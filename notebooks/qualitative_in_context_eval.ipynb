# %%
import sys
sys.path.append("../lib/")

import torch
from bert import *

# %%
# BUCHANAN

save_paths = [
    'trained_models/model.plsr.buchanan.allbuthomoyms.5k.300components.500max_iters',
    'trained_models/model.plsr.buchanan.allbuthomoyms.1k.300components.500max_iters',
    #'trained_models/model.plsr.buchanan.allbuthomoyms.glove.300components.300max_iters',
    'trained_models/model.ffnn.buchanan.allbuthomoyms.5k.50epochs.0.5dropout.lr1e-4.hsize300',
    'trained_models/model.ffnn.buchanan.allbuthomoyms.1k.50epochs.0.5dropout.lr1e-4.hsize300',
    #'trained_models/model.ffnn.buchanan.allbuthomoyms.glove.50epochs.0.5dropout.lr1e-4.hsize300',
    'trained_models/model.modabs.buchanan.allbuthomoyms.5k',
    'trained_models/model.modabs.buchanan.allbuthomoyms.1k',
    #'trained_models/model.modabs.buchanan.allbuthomoyms.glove'
]

# %%
#model = torch.load('model.60eps.5k.saved2')
models = {model: torch.load("../" + model) for model in save_paths}
#model = torch.load('model.30eps.5k.saved4')

# %%
models
# Out:
# {'trained_models/model.modabs.buchanan.mc_rae_real.5k': <modabs.MAD at 0x1461e1400>,
#  'trained_models/model.modabs.buchanan.mc_rae_real.1k': <modabs.MAD at 0x14620e340>,
#  'trained_models/model.plsr.buchanan.mc_rae_real.5k.100components.500max_iters': <plsr.PLSRClassifier at 0x14620e550>,
#  'trained_models/model.plsr.buchanan.mc_rae_real.1k.50components.500max_iters': <plsr.PLSRClassifier at 0x146223820>,
#  'trained_models/model.ffnn.buchanan.mc_rae_real.5k.50epochs.0.5dropout.lr1e-4.hsize300': <models.FeatureClassifier at 0x146223520>,
#  'trained_models/model.ffnn.buchanan.mc_rae_real.1k.50epochs.0.5dropout.lr1e-4.hsize300': <models.FeatureClassifier at 0x1461cbac0>}

# %%
verbs = [
'address',
'arrange',
'bend',
'break',
'check',
'complete',
'finish',
'fire',
'fix',
'grasp',
'load',
'name',
'operate',
'plant',
'prepare',
'produce',
'raise',
'report',
'roll',
'save',
'shine',
'spread',
'stuff',
'tie',
'toss',
'treat',
'twist'
]

nouns = ['thinking', 'knowledge', 'processing', 'premise', 'concept',
'constituency', 'historian', 'victory', 'chemical', 'prisoner',
'princess', 'photograph', 'furniture', 'dozen', 'leather', 'heaven',
'independence', 'pleasure', 'concern', 'mistake', 'protest', 'lesson',
'admission', 'mixture', 'participant', 'shoe', 'bottle', 'letter',
'pipe', 'library', 'variety', 'trust', 'conclusion', 'service',
'regulation', 'accommodation', 'change', 'pitch', 'analysis',
'pressure', 'earth', 'bridge', 'box', 'train', 'fire']

# %%
model.predict('wizard')
# Out:
# array([1.11223983e-12, 0.00000000e+00, 0.00000000e+00, ...,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
model.predict_top_n_features('chess',20)
# Out:
# ['baseball',
#  'green',
#  'gamble',
#  'round',
#  'insect',
#  'card',
#  'racket',
#  'board',
#  'net',
#  'court',
#  'sport',
#  'ball',
#  'king',
#  'play',
#  'strategy',
#  'piece',
#  'yellow',
#  'game',
#  'two',
#  'vegetable']

# %%
bert = BERTBase()
# Out:
# INFO:pytorch_pretrained_bert.modeling:loading archive file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased.tar.gz from cache at /Users/gabriellachronis/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba
# INFO:pytorch_pretrained_bert.modeling:extracting archive file /Users/gabriellachronis/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba to temp dir /var/folders/9m/vzvx58rs51v_x5nm620fz4xr0000gn/T/tmpu_uoxfnq
# INFO:pytorch_pretrained_bert.modeling:Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# INFO:pytorch_pretrained_bert.tokenization:loading vocabulary file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /Users/gabriellachronis/.pytorch_pretrained_bert/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084

# %%
sent = "'Or the surging whirling sounds of bats at night , when their black bodies dived into the blackness above and below the amber street lights"
sent = "The second largest order of mammals after rodents, bats comprise about 20% of all classified mammal species worldwide, with over 1,400 species"

model.predict_top_n_features_in_context('bats', sent, 10, bert=bert)
# Out:
# ['long',
#  'tail',
#  'fly',
#  'small',
#  'mammal',
#  'large',
#  'eat',
#  'leg',
#  'animal',
#  'fur']

# %%
model.predict_top_n_features('drill',10)
# Out:
# ['long',
#  'sharp',
#  'tool',
#  'object',
#  'loud',
#  'work',
#  'hand',
#  'move',
#  'metal',
#  'act']

# %%
model.predict_top_n_features_in_context('foundation', 'The argument has a weak foundation', 10, bert=bert)
# Out:
# ['house',
#  'water',
#  'material',
#  'protect',
#  'walk',
#  'person',
#  'object',
#  'hard',
#  'build',
#  'place']

# %%
model.predict_top_n_features_in_context('foundation', 'The building has a weak foundation', 10, bert=bert)
# Out:
# ['wood',
#  'house',
#  'human',
#  'heave',
#  'hand',
#  'object',
#  'hard',
#  'build',
#  'person',
#  'walk']

# %%
#sent = 'By the way, did everyone notice that misogynist pig served the ladies raw meat? '
sent = "People travel many miles to gaze upon this natural wonder, though few are willing to approach it closely, since it is reputed to be the haunt of various demons and devils"
#sent = "Early on, the target herd immunity threshold was estimated to be about 60 to 70 percent of the population. Most experts, including Dr. Fauci, expected that the United States would be able to reach it once vaccines were available"
for word in sent.split(' '):
    print(word)
    for model_name, model in models.items():
        feats = model.predict_top_n_features_in_context(word, sent,7, bert=bert)
        print(feats)
# Out:
# People
# ['made_of_plastic', 'has_a_tail', 'is_fast', 'has_4_legs', 'is_small', 'an_animal', 'beh_-_eats']
# ['is_long', 'beh_-_flies', 'is_fast', 'an_animal', 'is_brown', 'is_small', 'beh_-_eats']
# ['is_small', 'lives_in_water', 'has_legs', 'is_black', 'has_4_legs', 'has_a_tail', 'an_animal']
# ['beh_-_eats', 'has_wings', 'has_a_beak', 'has_feathers', 'an_animal', 'a_bird', 'beh_-_flies']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# travel
# ['made_of_metal', 'is_small', 'is_brown', 'made_of_plastic', 'is_long', 'used_for_transportation', 'is_fast']
# ['is_small', 'used_for_passengers', 'made_of_metal', 'is_long', 'is_black', 'is_fast', 'used_for_transportation']
# ['has_4_legs', 'used_for_transportation', 'is_large', 'an_animal', 'made_of_wood', 'is_long', 'made_of_leather']
# ['a_bird', 'has_4_legs', 'used_for_transportation', 'has_wheels', 'an_animal', 'made_of_wood', 'is_large']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# many
# ['is_long', 'is_fast', 'made_of_metal', 'made_of_plastic', 'is_black', 'is_small', 'has_fur']
# ['used_for_transportation', 'made_of_metal', 'is_small', 'is_electrical', 'is_fast', 'is_long', 'is_black']
# ['is_brown', 'is_fast', 'has_4_legs', 'is_large', 'is_long', 'is_black', 'an_animal']
# ['made_of_wood', 'is_large', 'beh_-_flies', 'has_feathers', 'has_wings', 'an_animal', 'a_bird']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# miles
# ['is_black', 'is_small', 'made_of_metal', 'is_fast', 'used_for_transportation', 'made_of_plastic', 'made_of_wood']
# ['has_wheels', 'made_of_metal', 'is_black', 'made_of_wood', 'is_fast', 'used_for_transportation', 'is_long']
# ['is_fast', 'is_small', 'is_long', 'made_of_wood', 'used_for_transportation', 'has_wheels', 'an_animal']
# ['an_animal', 'is_fast', 'used_for_storage', 'is_large', 'used_for_transportation', 'has_wheels', 'made_of_wood']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# to
# ['made_of_metal', 'is_brown', 'is_black', 'made_of_plastic', 'is_fast', 'made_of_wood', 'is_small']
# ['has_fur', 'is_fast', 'is_small', 'is_long', 'is_black', 'made_of_metal', 'made_of_wood']
# ['is_fast', 'used_for_storage', 'is_long', 'has_4_legs', 'an_animal', 'made_of_wood', 'is_large']
# ['tastes_sweet', 'has_4_legs', 'an_animal', 'has_wheels', 'made_of_wood', 'is_large', 'a_fruit']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# gaze
# ['is_large', 'is_breakable', 'is_brown', 'made_of_plastic', 'made_of_wood', 'an_animal', 'made_of_glass']
# ['made_of_glass', 'made_of_plastic', 'is_brown', 'has_fur', 'is_fast', 'is_small', 'is_black']
# ['made_of_wood', 'used_for_holding_things', 'made_of_glass', 'has_4_legs', 'made_of_plastic', 'is_brown', 'an_animal']
# ['a_mammal', 'has_4_legs', 'beh_-_swims', 'is_large', 'has_wheels', 'an_animal', 'made_of_wood']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# upon
# ['has_fur', 'has_teeth', 'is_long', 'is_brown', 'made_of_wood', 'is_large', 'made_of_plastic']
# ['tastes_sweet', 'is_brown', 'made_of_plastic', 'is_long', 'made_of_wood', 'is_black', 'is_small']
# ['lives_in_water', 'beh_-_swims', 'a_fruit', 'made_of_wood', 'is_small', 'tastes_sweet', 'an_animal']
# ['lives_in_water', 'made_of_wood', 'tastes_sweet', 'an_animal', 'a_fruit', 'is_large', 'beh_-_swims']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# this
# ['is_hard', 'is_green', 'has_fur', 'is_small', 'is_large', 'made_of_wood', 'has_4_legs']
# ['is_brown', 'a_mammal', 'has_4_legs', 'has_fur', 'made_of_wood', 'an_animal', 'is_small']
# ['a_mammal', 'has_a_tail', 'has_4_legs', 'is_green', 'is_small', 'a_fruit', 'an_animal']
# ['is_green', 'has_4_legs', 'is_juicy', 'is_small', 'an_animal', 'a_fruit', 'tastes_sweet']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# natural
# ['is_brown', 'is_hard', 'has_fur', 'is_small', 'has_a_tail', 'an_animal', 'is_green']
# ['has_a_tail', 'is_brown', 'made_of_wood', 'an_animal', 'has_4_legs', 'has_fur', 'is_small']
# ['a_fruit', 'is_hard', 'lives_in_water', 'an_animal', 'is_small', 'beh_-_swims', 'is_green']
# ['is_edible', 'beh_-_swims', 'lives_in_water', 'a_fruit', 'an_animal', 'is_green', 'is_small']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# wonder,
# ['made_of_plastic', 'is_large', 'is_tall', 'is_hard', 'is_round', 'is_small', 'made_of_wood']
# ['is_brown', 'made_of_wood', 'made_of_metal', 'has_fur', 'an_animal', 'is_round', 'is_small']
# ['is_hard', 'made_of_wood', 'is_round', 'lives_in_water', 'an_animal', 'beh_-_swims', 'is_small']
# ['beh_-_swims', 'lives_in_water', 'is_green', 'is_small', 'an_animal', 'is_round', 'made_of_wood']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# though
# ['has_feathers', 'beh_-_flies', 'an_animal', 'made_of_wood', 'has_wings', 'made_of_metal', 'is_small']
# ['clothing', 'is_fast', 'is_long', 'made_of_metal', 'made_of_wood', 'is_black', 'is_small']
# ['is_black', 'is_large', 'an_animal', 'is_long', 'used_for_transportation', 'is_small', 'has_wheels']
# ['beh_-_flies', 'made_of_wood', 'used_for_transportation', 'a_bird', 'has_wheels', 'is_large', 'an_animal']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# few
# ['is_edible', 'is_black', 'an_animal', 'has_fur', 'has_a_tail', 'is_long', 'a_fish']
# ['is_brown', 'hunted_by_people', 'a_fish', 'is_black', 'is_small', 'is_edible', 'is_long']
# ['has_a_tail', 'is_long', 'is_edible', 'beh_-_swims', 'a_fish', 'lives_in_water', 'an_animal']
# ['a_fish', 'beh_-_flies', 'an_animal', 'beh_-_swims', 'a_bird', 'has_feathers', 'lives_in_water']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# are
# ['is_large', 'made_of_metal', 'is_fast', 'made_of_wood', 'is_sharp', 'is_long', 'is_small']
# ['is_electrical', 'is_brown', 'is_small', 'made_of_metal', 'is_fast', 'is_long', 'is_black']
# ['has_a_tail', 'made_of_metal', 'has_wheels', 'has_4_legs', 'an_animal', 'made_of_leather', 'is_long']
# ['a_mammal', 'used_for_transportation', 'is_fast', 'has_4_legs', 'an_animal', 'has_wheels', 'is_large']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# willing
# ['has_seeds', 'tastes_good', 'is_brown', 'is_black', 'an_animal', 'is_edible', 'is_small']
# ['tastes_sweet', 'is_edible', 'is_brown', 'made_of_plastic', 'is_small', 'is_black', 'is_long']
# ['is_round', 'a_fruit', 'is_long', 'made_of_plastic', 'is_small', 'an_animal', 'made_of_metal']
# ['has_wings', 'made_of_metal', 'has_wheels', 'beh_-_flies', 'a_bird', 'is_large', 'an_animal']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# to
# ['made_of_metal', 'is_brown', 'is_black', 'made_of_plastic', 'is_fast', 'made_of_wood', 'is_small']
# ['has_fur', 'is_fast', 'is_small', 'is_long', 'is_black', 'made_of_metal', 'made_of_wood']
# ['is_fast', 'used_for_storage', 'is_long', 'has_4_legs', 'an_animal', 'made_of_wood', 'is_large']
# ['tastes_sweet', 'has_4_legs', 'an_animal', 'has_wheels', 'made_of_wood', 'is_large', 'a_fruit']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# approach
# ['tastes_sweet', 'has_a_beak', 'made_of_wood', 'made_of_plastic', 'an_animal', 'is_long', 'has_seeds']
# ['tastes_sweet', 'made_of_plastic', 'is_long', 'is_small', 'made_of_wood', 'made_of_metal', 'is_black']
# ['is_long', 'used_for_holding_things', 'made_of_glass', 'has_a_handle', 'made_of_plastic', 'has_wheels', 'an_animal']
# ['has_wings', 'an_animal', 'has_wheels', 'has_a_beak', 'a_bird', 'has_feathers', 'beh_-_flies']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# it
# ['is_tall', 'a_mammal', 'is_large', 'is_small', 'an_animal', 'made_of_wood', 'has_4_legs']
# ['a_mammal', 'is_round', 'has_4_legs', 'has_fur', 'an_animal', 'is_small', 'made_of_wood']
# ['is_round', 'is_hard', 'is_green', 'a_mammal', 'has_a_tail', 'has_4_legs', 'an_animal']
# ['a_mammal', 'beh_-_swims', 'is_round', 'has_4_legs', 'a_fruit', 'is_green', 'an_animal']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# closely,
# ['different_colours', 'made_of_metal', 'is_black', 'an_animal', 'is_long', 'is_small', 'made_of_wood']
# ['different_colours', 'has_fur', 'is_black', 'is_long', 'is_small', 'made_of_wood', 'made_of_metal']
# ['used_for_storage', 'an_animal', 'is_long', 'made_of_wood', 'is_brown', 'made_of_plastic', 'is_small']
# ['has_4_legs', 'is_small', 'made_of_metal', 'is_large', 'made_of_wood', 'used_for_storage', 'an_animal']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# since
# ['a_mammal', 'has_fur', 'has_4_legs', 'is_brown', 'an_animal', 'has_legs', 'is_small']
# ['has_4_legs', 'made_of_wood', 'has_fur', 'is_long', 'is_brown', 'an_animal', 'is_small']
# ['has_fur', 'has_legs', 'a_musical_instrument', 'has_4_legs', 'a_fruit', 'has_a_tail', 'an_animal']
# ['a_mammal', 'has_4_legs', 'has_legs', 'has_a_tail', 'a_bird', 'is_large', 'an_animal']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# it
# ['is_tall', 'a_mammal', 'is_large', 'is_small', 'an_animal', 'made_of_wood', 'has_4_legs']
# ['a_mammal', 'is_round', 'has_4_legs', 'has_fur', 'an_animal', 'is_small', 'made_of_wood']
# ['is_round', 'is_hard', 'is_green', 'a_mammal', 'has_a_tail', 'has_4_legs', 'an_animal']
# ['a_mammal', 'beh_-_swims', 'is_round', 'has_4_legs', 'a_fruit', 'is_green', 'an_animal']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# is
# ['is_fast', 'an_animal', 'has_legs', 'a_weapon', 'has_4_legs', 'is_small', 'is_long']
# ['made_of_glass', 'is_fast', 'is_dangerous', 'is_black', 'an_animal', 'a_weapon', 'is_small']
# ['is_long', 'an_animal', 'is_green', 'has_4_legs', 'has_fur', 'has_a_tail', 'is_small']
# ['a_mammal', 'has_4_legs', 'is_large', 'lives_in_water', 'beh_-_swims', 'is_small', 'an_animal']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# reputed
# ['is_rectangular', 'is_fast', 'is_green', 'has_seats', 'beh_-_flies', 'is_brown', 'is_long']
# ['a_weapon', 'beh_-_sings', 'made_of_wood', 'is_green', 'is_black', 'is_small', 'is_long']
# ['has_wheels', 'has_leaves', 'is_small', 'is_long', 'is_green', 'made_of_wood', 'a_tree']
# ['is_edible', 'made_of_wood', 'a_vegetable', 'has_wheels', 'a_weapon', 'is_green', 'is_long']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# to
# ['made_of_metal', 'is_brown', 'is_black', 'made_of_plastic', 'is_fast', 'made_of_wood', 'is_small']
# ['has_fur', 'is_fast', 'is_small', 'is_long', 'is_black', 'made_of_metal', 'made_of_wood']
# ['is_fast', 'used_for_storage', 'is_long', 'has_4_legs', 'an_animal', 'made_of_wood', 'is_large']
# ['tastes_sweet', 'has_4_legs', 'an_animal', 'has_wheels', 'made_of_wood', 'is_large', 'a_fruit']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# be
# ['a_weapon', 'is_large', 'has_fur', 'is_green', 'is_long', 'is_small', 'is_brown']
# ['has_fur', 'is_large', 'is_green', 'is_small', 'is_brown', 'a_weapon', 'is_black']
# ['beh_-_swims', 'is_edible', 'lives_in_water', 'a_weapon', 'is_green', 'an_animal', 'is_small']
# ['a_mammal', 'lives_in_water', 'a_weapon', 'has_4_legs', 'is_small', 'an_animal', 'is_green']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# the
# ['is_fast', 'is_large', 'is_brown', 'an_animal', 'has_fur', 'is_small', 'is_long']
# ['is_dangerous', 'is_green', 'is_large', 'is_long', 'a_weapon', 'is_black', 'is_small']
# ['tastes_sweet', 'a_weapon', 'a_vegetable', 'a_fruit', 'an_animal', 'is_green', 'is_small']
# ['lives_in_water', 'has_4_legs', 'an_animal', 'a_fruit', 'is_small', 'a_weapon', 'is_green']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# haunt
# ['made_of_plastic', 'has_wings', 'is_long', 'is_slimy', 'is_brown', 'used_for_storage', 'is_small']
# ['is_large', 'is_black', 'has_windows', 'beh_-_flies', 'used_for_storage', 'is_small', 'an_insect']
# ['an_insect', 'is_long', 'is_green', 'a_vegetable', 'made_of_wood', 'used_for_storage', 'is_small']
# ['beh_-_flies', 'is_long', 'a_vegetable', 'an_insect', 'used_for_storage', 'made_of_wood', 'is_small']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# of
# ['is_edible', 'has_4_legs', 'is_small', 'is_long', 'an_animal', 'is_fast', 'is_brown']
# ['has_wings', 'is_fast', 'used_for_storage', 'is_large', 'an_insect', 'is_small', 'is_black']
# ['has_wings', 'made_of_wood', 'used_for_storage', 'an_animal', 'a_bird', 'beh_-_flies', 'is_small']
# ['used_for_storage', 'beh_-_flies', 'a_bird', 'an_animal', 'has_feathers', 'is_green', 'is_small']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# various
# ['is_shiny', 'is_brown', 'a_vegetable', 'is_fast', 'is_large', 'is_black', 'is_small']
# ['is_fast', 'is_green', 'is_long', 'is_large', 'made_of_metal', 'is_black', 'is_small']
# ['beh_-_flies', 'is_black', 'is_small', 'is_large', 'is_green', 'a_vegetable', 'an_animal']
# ['beh_-_flies', 'is_large', 'is_small', 'a_vegetable', 'used_for_storage', 'an_animal', 'made_of_wood']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# demons
# ['has_seats', 'has_fur', 'a_mammal', 'is_black', 'is_fast', 'has_4_legs', 'is_large']
# ['used_for_praying', 'has_4_legs', 'an_animal', 'has_legs', 'is_black', 'is_small', 'is_large']
# ['has_4_legs', 'an_insect', 'is_black', 'has_legs', 'is_large', 'has_wheels', 'an_animal']
# ['has_4_legs', 'is_large', 'is_black', 'is_fast', 'has_wheels', 'an_insect', 'an_animal']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# and
# ['is_black', 'is_fast', 'has_4_legs', 'is_dangerous', 'is_long', 'is_small', 'is_brown']
# ['a_weapon', 'is_long', 'an_insect', 'made_of_metal', 'is_large', 'is_black', 'is_small']
# ['an_insect', 'is_black', 'is_sharp', 'a_tool', 'a_vegetable', 'is_green', 'is_long']
# ['is_long', 'is_green', 'made_of_metal', 'is_small', 'made_of_wood', 'is_sharp', 'a_vegetable']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']
# devils
# ['used_for_worshipping', 'a_mammal', 'is_large', 'is_brown', 'is_black', 'has_seats', 'has_clergy']
# ['is_quiet', 'is_green', 'is_small', 'is_black', 'is_large', 'an_animal', 'has_legs']
# ['is_brown', 'is_long', 'is_large', 'is_small', 'is_black', 'an_insect', 'an_animal']
# ['is_brown', 'has_legs', 'has_4_legs', 'is_large', 'is_black', 'an_animal', 'an_insect']
# ['is_long', 'made_of_metal', 'has_wings', 'beh_-_flies', 'is_small', 'is_warm', 'is_black']
# ['is_black', 'is_electrical', 'is_long', 'is_small', 'is_round', 'made_of_metal', 'made_of_plastic']

# %%
model.predict_top_n_features_in_context('pig', 'In fact with the development of deep-litter hen houses and intensive pig culture some such controls are necessary', 20, bert=bert)
# Out:
# ['water',
#  'food',
#  'wing',
#  'hunt',
#  'small',
#  'brown',
#  'beak',
#  'farm',
#  'white',
#  'fly',
#  'large',
#  'feather',
#  'tail',
#  'fur',
#  'animal',
#  'bird',
#  'four',
#  'mammal',
#  'eat',
#  'leg']

# %%
sent = " My place is an absolute pig sty and I have to do laundry Hahahahaha"
model.predict_top_n_features_in_context('pig', sent, 20, bert=bert)
# Out:
# ['instrument',
#  'person',
#  'dirt',
#  'brown',
#  'meat',
#  'tail',
#  'large',
#  'fur',
#  'water',
#  'leg',
#  'farm',
#  'wheel',
#  'food',
#  'four',
#  'music',
#  'eat',
#  'metal',
#  'animal',
#  'black',
#  'mammal']

# %%
model.predict_top_n_features_in_context('sharks', 'We saw sharks, rays, els, turtles, lobsters, crabs, hundreds and hundreds of', 20, bert=bert)
# Out:
# ['danger',
#  'scale',
#  'good',
#  'wood',
#  'mouth',
#  'tail',
#  'boat',
#  'mammal',
#  'eat',
#  'fish',
#  'large',
#  'water',
#  'teeth',
#  'person',
#  'swim',
#  'leg',
#  'ocean',
#  'animal',
#  'hunt',
#  'long']

# %%
model.predict_top_n_features_in_context('shark', "kill what is the same product of rape.... you have simply jumped the logical shark.... it's as simple as that. # We can argue the political and", 10, bert=bert)
# Out:
# ['person',
#  'metal',
#  'large',
#  'fly',
#  'swim',
#  'fish',
#  'bird',
#  'animal',
#  'water',
#  'eat']

# %%
model.predict_top_n_features_in_context('shark', "offended by the Poll # The character's name has become a synonym for loan shark, and as a verb to shylock means to lend money at exorbitant rates.", 20, bert=bert)
# Out:
# ['long',
#  'danger',
#  'fur',
#  'teeth',
#  'tail',
#  'fish',
#  'hunt',
#  'mammal',
#  'four',
#  'act',
#  'swim',
#  'give',
#  'large',
#  'eat',
#  'leg',
#  'water',
#  'person',
#  'human',
#  'animal',
#  'money']

# %%
word = "production"
sents = ["Here we must stress again that we are not proposing that the category of production should magically disappear, but that we depose it from the metaphysical primacy it has enjoyed for far too long in Western history, especially following the rise of capitalism."
        , "Her visit was in conjunction with the School of Theater's production of \" The Laramie Project, \" a play about Shepard's gay son,"
        , "Agriculture is the birth of production, complete with its essential features and deformation of life and consciousness"
        , "How to achieve such a seizure of the means of production is a political question"
        , "The rig had been expected to begin oil production again later this month"]

# %%
for sent in sents:
    features = model.predict_top_n_features_in_context(word, sent, 20, bert=bert)
    print(features)
# Out:
# ['up', 'tool', 'build', 'bad', 'place', 'store', 'dirt', 'act', 'give', 'large', 'person', 'human', 'farm', 'object', 'good', 'money', 'animal', 'body', 'country', 'work']
# ['store', 'window', 'book', 'air', 'group', 'place', 'vehicle', 'loud', 'noise', 'transport', 'sport', 'mouth', 'word', 'human', 'light', 'person', 'fun', 'large', 'funny', 'wheel']
# ['hand', 'more', 'country', 'grow', 'dirt', 'cloth', 'up', 'farm', 'object', 'bad', 'animal', 'give', 'person', 'act', 'body', 'human', 'good', 'work', 'money', 'food']
# ['make', 'animal', 'one', 'hold', 'place', 'work', 'good', 'object', 'give', 'four', 'large', 'together', 'tool', 'money', 'act', 'wheel', 'metal', 'person', 'wood', 'human']
# ['egg', 'sharp', 'fish', 'air', 'fly', 'metal', 'wing', 'place', 'feather', 'high', 'noise', 'mouth', 'beak', 'loud', 'fire', 'work', 'kill', 'weapon', 'bird', 'food']

# %%
word = "gravel"
sents = [
    "My wheel turned to the left and down a gravel road."
    , "The speaker's voice was guttural and low, low and full of gravel and flecks of spit."
]

for sent in sents:
    print(sent)
    print()
    for model in models.values():
        features = model.predict_top_n_features_in_context(word, sent, 20, bert=bert)
        print(features)
        print()
# Out:
# My wheel turned to the left and down a gravel road.
#
# ['color', 'stone', 'ground', 'brown', 'sand', 'wheel', 'vehicle', 'white', 'water', 'land', 'earth', 'black', 'farm', 'small', 'car', 'road', 'dirt', 'hard', 'drive', 'rock']
#
# ['field', 'beach', 'place', 'house', 'land', 'brown', 'small', 'wheel', 'rock', 'farm', 'road', 'vehicle', 'sand', 'car', 'dirt', 'drive', 'water', 'hard', 'black', 'piece']
#
# ['wood', 'house', 'four', 'soft', 'grass', 'water', 'white', 'wheel', 'drink', 'brown', 'car', 'rock', 'color', 'tree', 'drive', 'black', 'hard', 'dirt', 'small', 'road']
#
# ['piece', 'brown', 'transport', 'black', 'child', 'wheel', 'car', 'hard', 'color', 'soft', 'dirt', 'stone', 'horse', 'white', 'drive', 'place', 'small', 'road', 'play', 'rock']
#
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
#
# ['soft', 'grain', 'beach', 'soil', 'mud', 'grow', 'plant', 'ground', 'wet', 'hard', 'dirt', 'small', 'road', 'earth', 'rock', 'drive', 'sand', 'brown', 'stone', 'pebble']
#
# The speaker's voice was guttural and low, low and full of gravel and flecks of spit.
#
# ['water', 'car', 'drive', 'road', 'voice', 'act', 'mouth', 'earth', 'bad', 'ground', 'place', 'hard', 'soft', 'pitch', 'rock', 'noise', 'dirt', 'loud', 'sound', 'small']
#
# ['annoy', 'act', 'sound', 'pitch', 'hard', 'mouth', 'feel', 'earth', 'voice', 'ground', 'cover', 'dirt', 'dog', 'rock', 'small', 'bad', 'loud', 'soft', 'noise', 'place']
#
# ['pitch', 'voice', 'soft', 'smell', 'hard', 'loud', 'sound', 'drive', 'act', 'dirt', 'mouth', 'small', 'green', 'rock', 'drink', 'noise', 'tree', 'plant', 'grow', 'car']
#
# ['stone', 'drink', 'ground', 'noise', 'car', 'sound', 'mouth', 'rock', 'small', 'loud', 'earth', 'hard', 'brown', 'white', 'green', 'clean', 'tree', 'smell', 'dirt', 'grow']
#
# ['wet', 'soil', 'beach', 'grow', 'road', 'plant', 'clean', 'ground', 'earth', 'worm', 'grain', 'mud', 'brown', 'dirt', 'drive', 'sand', 'small', 'rock', 'pebble', 'stone']
#
# ['soft', 'grain', 'beach', 'soil', 'mud', 'grow', 'plant', 'ground', 'wet', 'hard', 'dirt', 'small', 'road', 'earth', 'rock', 'drive', 'sand', 'brown', 'stone', 'pebble']

# %%
word = "pig"
sents = [
    "The pig trotted up to the fence."
    , "My roommate acts like such a pig; she never does the dishes."
]


for sent in sents:
    print(sent)
    print()
    for model in models.values():
        features = model.predict_top_n_features_in_context(word, sent, 20, bert=bert)
        print(features)
        print()
# Out:
# The pig trotted up to the fence.
#
# ['brown', 'cute', 'white', 'smell', 'long', 'big', 'large', 'domestic', 'hair', 'farm', 'animal', 'food', 'fur', 'mammal', 'pet', 'tail', 'leg', 'eat', 'small', 'four']
#
# ['white', 'dirt', 'gray', 'big', 'food', 'domestic', 'farm', 'eat', 'four', 'mammal', 'pet', 'small', 'animal', 'leg', 'smell', 'black', 'cute', 'hair', 'tail', 'fur']
#
# ['child', 'wheel', 'pet', 'white', 'four', 'horse', 'animal', 'tail', 'long', 'large', 'eat', 'water', 'fur', 'mammal', 'small', 'brown', 'cow', 'farm', 'leg', 'as']
#
# ['milk', 'black', 'brown', 'water', 'swim', 'horse', 'fur', 'mammal', 'pet', 'eat', 'leg', 'animal', 'white', 'food', 'large', 'long', 'four', 'tail', 'farm', 'small']
#
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
#
# ['squeal', 'pork', 'pet', 'fat', 'smell', 'mammal', 'mud', 'dirt', 'oink', 'tail', 'bacon', 'curl', 'four', 'snout', 'pink', 'animal', 'farm', 'leg', 'as', 'eat']
#
# My roommate acts like such a pig; she never does the dishes.
#
# ['big', 'water', 'round', 'brown', 'tail', 'smell', 'dirt', 'pet', 'white', 'farm', 'large', 'fur', 'animal', 'small', 'person', 'eat', 'leg', 'food', 'four', 'mammal']
#
# ['domestic', 'live', 'farm', 'mammal', 'tail', 'small', 'pet', 'leg', 'food', 'fur', 'smell', 'big', 'animal', 'person', 'living', 'four', 'dirt', 'large', 'size', 'eat']
#
# ['cow', 'swim', 'smell', 'food', 'dirt', 'tail', 'work', 'white', 'brown', 'farm', 'clean', 'feel', 'mammal', 'time', 'animal', 'fur', 'wear', 'person', 'eat', 'water']
#
# ['day', 'swim', 'woman', 'as', 'female', 'mammal', 'tail', 'brown', 'smell', 'four', 'water', 'farm', 'white', 'large', 'food', 'eat', 'fur', 'person', 'animal', 'leg']
#
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
#
# ['squeal', 'pork', 'pet', 'fat', 'smell', 'mammal', 'mud', 'dirt', 'oink', 'tail', 'bacon', 'curl', 'four', 'snout', 'pink', 'animal', 'farm', 'leg', 'as', 'eat']

# %%
word = "chess"
sents = [
    "Old men sat around in the park waiting for acquantances to meet them for a game of chess."
    , "Sam faced up his opponent in the ring. He bounced off the ropes and swund underneath for an uppercut. This wasn't war. This was chess."
]

word = "can"
sents = [
    " Now the can is open and it turns out it was full of worms indeed.",
    "By the way send a can of food to the Red Cross.",
    "Drain the liquid out of one big 20-ounce can of yams."

]


for sent in sents:
    print(sent)
    print()
    for model in models.values():
        features = model.predict_top_n_features_in_context(word, sent, 20, bert=bert)
        print(features)
        print()
# Out:
#  Now the can is open and it turns out it was full of worms indeed.
#
# ['use', 'door', 'thing', 'animal', 'large', 'hand', 'water', 'kitchen', 'liquid', 'store', 'carry', 'human', 'object', 'plastic', 'round', 'contain', 'metal', 'small', 'food', 'hold']
#
# ['human', 'animal', 'liquid', 'four', 'hold', 'door', 'metal', 'hand', 'food', 'kitchen', 'large', 'store', 'small', 'round', 'carry', 'plastic', 'object', 'water', 'thing', 'contain']
#
# ['cold', 'carry', 'mouth', 'wheel', 'door', 'liquid', 'wood', 'contain', 'hand', 'large', 'store', 'metal', 'hold', 'small', 'kitchen', 'thing', 'food', 'plastic', 'cook', 'water']
#
# ['door', 'liquid', 'four', 'eat', 'round', 'water', 'plastic', 'thing', 'metal', 'contain', 'wheel', 'small', 'large', 'wood', 'kitchen', 'food', 'carry', 'hand', 'store', 'hold']
#
# ['jar', 'object', 'transparent', 'break', 'cardboard', 'item', 'drink', 'plastic', 'lid', 'thing', 'hold', 'box', 'recycle', 'liquid', 'aluminum', 'metal', 'glass', 'soda', 'contain', 'food']
#
# ['cardboard', 'neck', 'hand', 'item', 'liquid', 'break', 'aluminum', 'metal', 'food', 'lid', 'glass', 'hold', 'thing', 'plastic', 'box', 'contain', 'recycle', 'transparent', 'soda', 'drink']
#
# By the way send a can of food to the Red Cross.
#
# ['kitchen', 'drink', 'store', 'liquid', 'glass', 'object', 'animal', 'small', 'carry', 'hand', 'food', 'metal', 'contain', 'plastic', 'human', 'thing', 'round', 'large', 'paper', 'hold']
#
# ['four', 'object', 'glass', 'human', 'drink', 'carry', 'measure', 'animal', 'thing', 'store', 'liquid', 'round', 'plastic', 'large', 'hand', 'contain', 'food', 'small', 'metal', 'hold']
#
# ['round', 'cook', 'piece', 'wheel', 'contain', 'glass', 'carry', 'plastic', 'food', 'small', 'liquid', 'hand', 'thing', 'drink', 'metal', 'wood', 'store', 'measure', 'large', 'hold']
#
# ['glass', 'store', 'kitchen', 'liquid', 'contain', 'small', 'drink', 'wood', 'hold', 'round', 'wheel', 'eat', 'metal', 'carry', 'large', 'plastic', 'food', 'hand', 'measure', 'thing']
#
# ['green', 'milk', 'box', 'transparent', 'thing', 'cardboard', 'plastic', 'glass', 'liquid', 'break', 'neck', 'drink', 'lid', 'hold', 'contain', 'soda', 'aluminum', 'metal', 'recycle', 'food']
#
# ['cardboard', 'neck', 'hand', 'item', 'liquid', 'break', 'aluminum', 'metal', 'food', 'lid', 'glass', 'hold', 'thing', 'plastic', 'box', 'contain', 'recycle', 'transparent', 'soda', 'drink']
#
# Drain the liquid out of one big 20-ounce can of yams.
#
# ['animal', 'paper', 'use', 'kitchen', 'glass', 'thing', 'contain', 'small', 'metal', 'drink', 'liquid', 'water', 'hand', 'large', 'hold', 'carry', 'plastic', 'food', 'store', 'round']
#
# ['paper', 'kitchen', 'measure', 'hand', 'glass', 'milk', 'thing', 'water', 'small', 'round', 'large', 'carry', 'drink', 'liquid', 'hold', 'store', 'plastic', 'food', 'metal', 'contain']
#
# ['transport', 'contain', 'animal', 'hand', 'store', 'carry', 'hold', 'small', 'large', 'plastic', 'measure', 'wood', 'drink', 'liquid', 'thing', 'mouth', 'glass', 'wheel', 'food', 'four']
#
# ['instrument', 'liquid', 'hand', 'drink', 'contain', 'hold', 'wheel', 'carry', 'large', 'round', 'glass', 'thing', 'food', 'lid', 'small', 'store', 'measure', 'kitchen', 'music', 'plastic']
#
# ['green', 'milk', 'box', 'transparent', 'thing', 'cardboard', 'plastic', 'glass', 'liquid', 'break', 'neck', 'drink', 'lid', 'hold', 'contain', 'soda', 'aluminum', 'metal', 'recycle', 'food']
#
# ['cardboard', 'neck', 'hand', 'item', 'liquid', 'break', 'aluminum', 'metal', 'food', 'lid', 'glass', 'hold', 'thing', 'plastic', 'box', 'contain', 'recycle', 'transparent', 'soda', 'drink']

# %%
word = "cans"
sents = [
    "Pour a can of soda (12 oz) 2-12 oz cans of soda into the cake mix two boxes of cake mix.",
    "It takes a lot of energy and manpower to collect aluminum cans for example.",
    "Drain the liquid out of two big 20-ounce cans of yams."
]

for sent in sents:
    print(sent)
    print()
    for model in models.values():
        features = model.predict_top_n_features_in_context(word, sent, 20, bert=bert)
        print(features)
        print()
# Out:
# Pour a can of soda (12 oz) 2-12 oz cans of soda into the cake mix two boxes of cake mix.
#
# ['cold', 'contain', 'large', 'thing', 'food', 'place', 'fire', 'door', 'liquid', 'glass', 'kitchen', 'plastic', 'hand', 'small', 'metal', 'loud', 'hold', 'danger', 'measure', 'drink']
#
# ['weapon', 'place', 'thing', 'kitchen', 'kill', 'glass', 'fire', 'danger', 'small', 'hand', 'food', 'measure', 'liquid', 'drink', 'loud', 'hold', 'metal', 'contain', 'large', 'plastic']
#
# ['warm', 'carry', 'plastic', 'glass', 'food', 'piece', 'large', 'small', 'loud', 'alcohol', 'hand', 'fire', 'hold', 'metal', 'thing', 'measure', 'noise', 'drink', 'liquid', 'wear']
#
# ['store', 'carry', 'noise', 'wood', 'plastic', 'glass', 'hand', 'large', 'fire', 'liquid', 'drink', 'thing', 'loud', 'contain', 'small', 'round', 'hold', 'metal', 'measure', 'food']
#
# ['green', 'milk', 'box', 'transparent', 'thing', 'cardboard', 'plastic', 'glass', 'liquid', 'break', 'neck', 'drink', 'lid', 'hold', 'contain', 'soda', 'aluminum', 'metal', 'recycle', 'food']
#
# ['cardboard', 'neck', 'hand', 'item', 'liquid', 'break', 'aluminum', 'metal', 'food', 'lid', 'glass', 'hold', 'thing', 'plastic', 'box', 'contain', 'recycle', 'transparent', 'soda', 'drink']
#
# It takes a lot of energy and manpower to collect aluminum cans for example.
#
# ['object', 'cloth', 'wood', 'glass', 'kitchen', 'liquid', 'thing', 'door', 'material', 'hand', 'wear', 'store', 'small', 'food', 'large', 'color', 'metal', 'plastic', 'contain', 'hold']
#
# ['liquid', 'long', 'thing', 'glass', 'human', 'wear', 'hand', 'contain', 'color', 'metal', 'hold', 'plastic', 'store', 'food', 'wood', 'material', 'small', 'object', 'door', 'large']
#
# ['carry', 'round', 'large', 'drink', 'metal', 'wood', 'hold', 'contain', 'door', 'liquid', 'store', 'plastic', 'glass', 'hand', 'wheel', 'color', 'cloth', 'clean', 'food', 'thing']
#
# ['noise', 'large', 'small', 'smell', 'carry', 'kitchen', 'animal', 'liquid', 'act', 'glass', 'contain', 'hand', 'food', 'store', 'thing', 'color', 'wood', 'plastic', 'hold', 'metal']
#
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
#
# ['cardboard', 'neck', 'hand', 'item', 'liquid', 'break', 'aluminum', 'metal', 'food', 'lid', 'glass', 'hold', 'thing', 'plastic', 'box', 'contain', 'recycle', 'transparent', 'soda', 'drink']
#
# Drain the liquid out of two big 20-ounce cans of yams.
#
# ['hand', 'break', 'hold', 'food', 'paper', 'metal', 'water', 'large', 'kitchen', 'round', 'liquid', 'plastic', 'small', 'contain', 'glass', 'store', 'thing', 'color', 'carry', 'drink']
#
# ['milk', 'color', 'paper', 'break', 'store', 'carry', 'metal', 'hold', 'round', 'food', 'liquid', 'thing', 'water', 'large', 'plastic', 'small', 'glass', 'kitchen', 'drink', 'contain']
#
# ['piece', 'metal', 'carry', 'measure', 'four', 'wood', 'kitchen', 'water', 'drink', 'liquid', 'mouth', 'animal', 'hold', 'plastic', 'food', 'glass', 'large', 'store', 'thing', 'small']
#
# ['child', 'thing', 'hold', 'measure', 'break', 'liquid', 'contain', 'drink', 'carry', 'glass', 'store', 'food', 'hand', 'round', 'music', 'metal', 'small', 'kitchen', 'plastic', 'lid']
#
# ['green', 'milk', 'box', 'transparent', 'thing', 'cardboard', 'plastic', 'glass', 'liquid', 'break', 'neck', 'drink', 'lid', 'hold', 'contain', 'soda', 'aluminum', 'metal', 'recycle', 'food']
#
# ['cardboard', 'neck', 'hand', 'item', 'liquid', 'break', 'aluminum', 'metal', 'food', 'lid', 'glass', 'hold', 'thing', 'plastic', 'box', 'contain', 'recycle', 'transparent', 'soda', 'drink']

# %%
import pandas as pd
df = pd.read_csv('results/lappin_clusters_nouns_only.csv')
df
# Out:
#           word  K  layer  cluster_id  \
# 0     thinking  8      5           0
# 1     thinking  8      5           0
# 2     thinking  8      5           0
# 3     thinking  8      5           0
# 4     thinking  8      5           0
# ...        ... ..    ...         ...
# 4539      fire  8      5           4
# 4540      fire  8      5           4
# 4541      fire  8      5           4
# 4542      fire  8      5           4
# 4543      fire  8      5           4
#
#                                                sentence
# 0     By not considering these interests explicitly ...
# 1     His diffidence blinded him to the truth that t...
# 2     The incorporation of a long passage from a Boa...
# 3     I therefore proposed an account of law , ‘ nor...
# 4     There had to be a variation in our sorting pro...
# ...                                                 ...
# 4539            That 's when the fire brigade arrived .
# 4540  A JEALOUS lover sent fire engines and ambulanc...
# 4541  But it would not do to show any emotion before...
# 4542                                Fire cover pressure
# 4543                           There are fire hazards .
#
# [4544 rows x 5 columns]

# %%
samples = []

for noun in df.word.unique():
    sentences = df[df['word'] == noun]
    length = len(sentences)
    #print(noun)
    #print(length)
    for cluster_id in range (0,5):
        cluster_sentences = sentences[sentences['cluster_id'] == cluster_id]
        #print(cluster_sentences)
        sample = cluster_sentences.sample(random_state=1)
        samples.append(sample)

samples = pd.concat(samples)
samples
# Out:
#           word  K  layer  cluster_id  \
# 14    thinking  8      5           0
# 31    thinking  8      5           1
# 42    thinking  8      5           2
# 48    thinking  8      5           3
# 62    thinking  8      5           4
# ...        ... ..    ...         ...
# 4456      fire  8      5           0
# 4480      fire  8      5           1
# 4499      fire  8      5           2
# 4520      fire  8      5           3
# 4538      fire  8      5           4
#
#                                                sentence
# 14    The project proposes to find out how far the t...
# 31    It 's really depressing and you 've got to sto...
# 42    Without thinking , as though there were nothin...
# 48    And it also managed to chip some of the woodwo...
# 62    Positive thinking is encouraged as they ‘ comp...
# ...                                                 ...
# 4456  The close-up of the ribbons , preceded by a sh...
# 4480  Ironically it seems that the personal computer...
# 4499  That way he can not be targeted by missile fir...
# 4520  After deliberating for a little while , the pr...
# 4538  Perhaps the best thing to do , I thought despa...
#
# [225 rows x 5 columns]

# %%
for noun in df.word.unique():
    this_word = samples[samples['word'] == noun]
    print(noun)
    print()
    for index, row in this_word.iterrows():
        print(row.sentence)
        
        for model in models.values():
            features = model.predict_top_n_features_in_context(noun, row.sentence, 20, bert=bert)
            print(features)
        print()
        print()
# Out:
# thinking
#
# The project proposes to find out how far the thinking of these pupils can be advanced , over a period of two years , to give them access to concepts which hitherto they would not have had .
# ['human', 'school', 'one', 'know', 'act', 'person', 'speak', 'eat', 'language', 'feel', 'mouth', 'thought', 'brain', 'mind', 'word', 'think', 'communicate', 'plan', 'science', 'idea']
# ['speak', 'paper', 'science', 'one', 'communicate', 'school', 'language', 'plan', 'mouth', 'word', 'brain', 'eat', 'think', 'mind', 'act', 'know', 'feel', 'thought', 'idea', 'person']
# ['talk', 'write', 'human', 'see', 'communicate', 'mouth', 'way', 'body', 'science', 'mind', 'feel', 'brain', 'person', 'think', 'money', 'idea', 'thought', 'word', 'know', 'act']
# ['fly', 'person', 'act', 'understand', 'wear', 'communicate', 'number', 'feel', 'mind', 'write', 'mouth', 'word', 'know', 'idea', 'brain', 'money', 'bird', 'think', 'feather', 'thought']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['process', 'body', 'consider', 'mental', 'speak', 'talk', 'converse', 'voice', 'human', 'mouth', 'act', 'person', 'word', 'communicate', 'mind', 'brain', 'ponder', 'think', 'idea', 'thought']
#
#
# It 's really depressing and you 've got to stop thinking about it , 'cause if you do n't then the emotions will come and you start crying , and you sort of think to yourself , ‘ No I 've got to stop thinking , I 've got to do something . ’
# ['part', 'sleep', 'inform', 'water', 'eye', 'intent', 'mouth', 'communicate', 'body', 'love', 'bad', 'look', 'word', 'brain', 'think', 'idea', 'thought', 'feel', 'mind', 'act']
# ['look', 'paper', 'love', 'liquid', 'bad', 'sleep', 'human', 'word', 'act', 'communicate', 'mind', 'intent', 'feel', 'thought', 'idea', 'water', 'body', 'think', 'brain', 'hard']
# ['time', 'play', 'eye', 'mind', 'brain', 'thought', 'idea', 'sleep', 'fish', 'move', 'swim', 'food', 'eat', 'person', 'mouth', 'human', 'water', 'act', 'feel', 'think']
# ['eye', 'close', 'communicate', 'word', 'thought', 'part', 'write', 'brain', 'human', 'idea', 'time', 'act', 'body', 'think', 'feel', 'mouth', 'move', 'mind', 'sleep', 'water']
# ['eye', 'future', 'ahead', 'sense', 'touch', 'prepare', 'organize', 'intelligent', 'think', 'process', 'ponder', 'plan', 'act', 'mental', 'body', 'consider', 'idea', 'brain', 'mind', 'thought']
# ['process', 'body', 'consider', 'mental', 'speak', 'talk', 'converse', 'voice', 'human', 'mouth', 'act', 'person', 'word', 'communicate', 'mind', 'brain', 'ponder', 'think', 'idea', 'thought']
#
#
# Without thinking , as though there were nothing else she could do , she slipped her hand in under her thick shirt .
# ['see', 'question', 'lung', 'plan', 'mouth', 'word', 'think', 'look', 'paper', 'know', 'act', 'thought', 'water', 'aware', 'idea', 'round', 'mind', 'body', 'brain', 'write']
# ['scare', 'paper', 'look', 'kitchen', 'word', 'lung', 'plan', 'eye', 'body', 'question', 'aware', 'life', 'know', 'mouth', 'act', 'think', 'brain', 'idea', 'mind', 'thought']
# ['sound', 'eye', 'act', 'see', 'food', 'thought', 'wear', 'time', 'animal', 'body', 'brain', 'loud', 'idea', 'sleep', 'water', 'know', 'metal', 'noise', 'think', 'money']
# ['move', 'fish', 'body', 'look', 'act', 'write', 'see', 'mind', 'idea', 'know', 'eye', 'feel', 'long', 'think', 'time', 'eat', 'animal', 'brain', 'thought', 'metal']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['process', 'body', 'consider', 'mental', 'speak', 'talk', 'converse', 'voice', 'human', 'mouth', 'act', 'person', 'word', 'communicate', 'mind', 'brain', 'ponder', 'think', 'idea', 'thought']
#
#
# And it also managed to chip some of the woodwork , curious to think that I was offered as war damage compensation five pounds to re-case the piano , you could n't of had it repolished for five pounds , but thinking was working class people should n't have pianos , I 'm certain that was at the back of , of the gentleman whose job it was to evaluate war damage , he certainly raised his eyebrows every time we told him , what either a piece of furniture or crockery or cutlery which had been destroyed had cost and he was so foolish after er the house had been almost flattened as de demand bills as proof of evidence that your figures were correct
# ['mind', 'feel', 'communicate', 'write', 'mouth', 'speak', 'inform', 'water', 'think', 'green', 'idea', 'thought', 'know', 'good', 'word', 'act', 'brain', 'person', 'opinion', 'group']
# ['inform', 'taste', 'plant', 'group', 'grow', 'act', 'warm', 'idea', 'direct', 'speak', 'food', 'green', 'eat', 'opinion', 'good', 'know', 'person', 'water', 'think', 'thought']
# ['mind', 'taste', 'direct', 'end', 'eat', 'idea', 'door', 'know', 'group', 'food', 'plant', 'green', 'grow', 'thought', 'leave', 'person', 'move', 'think', 'fruit', 'vegetable']
# ['communicate', 'mind', 'word', 'music', 'group', 'wood', 'thought', 'tree', 'idea', 'vegetable', 'write', 'know', 'eat', 'think', 'water', 'green', 'fruit', 'grow', 'taste', 'person']
# ['TRUE', 'cut', 'soft', 'trust', 'hand', 'fabric', 'emotion', 'brain', 'think', 'ponder', 'act', 'process', 'consider', 'mental', 'thought', 'idea', 'faith', 'touch', 'sense', 'mind']
# ['process', 'body', 'consider', 'mental', 'speak', 'talk', 'converse', 'voice', 'human', 'mouth', 'act', 'person', 'word', 'communicate', 'mind', 'brain', 'ponder', 'think', 'idea', 'thought']
#
#
# Positive thinking is encouraged as they ‘ compare legs ’ .
# ['express', 'language', 'look', 'communicate', 'thought', 'brain', 'one', 'act', 'know', 'good', 'word', 'mind', 'speak', 'idea', 'mouth', 'think', 'feel', 'person', 'write', 'school']
# ['one', 'run', 'child', 'small', 'school', 'cloth', 'speak', 'walk', 'ocean', 'word', 'look', 'communicate', 'mind', 'act', 'thought', 'feel', 'think', 'idea', 'brain', 'mouth']
# ['water', 'fish', 'food', 'think', 'word', 'brain', 'human', 'mouth', 'feel', 'eat', 'sport', 'communicate', 'mind', 'write', 'noise', 'thought', 'end', 'idea', 'money', 'act']
# ['teeth', 'child', 'understand', 'human', 'cloth', 'language', 'school', 'act', 'wear', 'mind', 'communicate', 'mouth', 'word', 'thought', 'idea', 'feel', 'brain', 'write', 'think', 'know']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['process', 'body', 'consider', 'mental', 'speak', 'talk', 'converse', 'voice', 'human', 'mouth', 'act', 'person', 'word', 'communicate', 'mind', 'brain', 'ponder', 'think', 'idea', 'thought']
#
#
# knowledge
#
# A spokeswoman for the Chippendales said : ‘ We do n't deal with the theatres direct but I have no knowledge of this at all . ’
# ['able', 'grow', 'object', 'see', 'language', 'help', 'move', 'money', 'body', 'direct', 'school', 'long', 'communicate', 'work', 'understand', 'human', 'act', 'know', 'learn', 'inform']
# ['pass', 'express', 'see', 'language', 'direct', 'tool', 'intent', 'help', 'learn', 'communicate', 'body', 'move', 'work', 'human', 'object', 'understand', 'act', 'long', 'inform', 'know']
# ['eye', 'sharp', 'wood', 'school', 'tool', 'end', 'able', 'money', 'inform', 'understand', 'object', 'time', 'know', 'human', 'move', 'question', 'fast', 'person', 'see', 'act']
# ['teach', 'help', 'tell', 'question', 'talk', 'communicate', 'hand', 'act', 'know', 'black', 'see', 'car', 'inform', 'store', 'eye', 'wood', 'understand', 'human', 'move', 'person']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['aware', 'number', 'view', 'able', 'comprehend', 'skill', 'smart', 'brain', 'hold', 'intelligent', 'know', 'experience', 'fact', 'alert', 'learn', 'understand', 'data', 'school', 'inform', 'wise']
#
#
# In the USA teacher competency tests are also included ; these test teacher knowledge .
# ['capable', 'smart', 'see', 'skill', 'book', 'complete', 'tell', 'think', 'teach', 'cook', 'able', 'inform', 'know', 'school', 'TRUE', 'feel', 'college', 'learn', 'food', 'understand']
# ['understand', 'skill', 'tell', 'liquid', 'teach', 'complete', 'plant', 'stick', 'capable', 'work', 'learn', 'water', 'able', 'cook', 'up', 'school', 'food', 'know', 'TRUE', 'inform']
# ['right', 'child', 'write', 'language', 'book', 'food', 'understand', 'learn', 'inform', 'word', 'eat', 'smart', 'female', 'school', 'move', 'number', 'able', 'feel', 'person', 'know']
# ['act', 'good', 'new', 'sense', 'hand', 'skill', 'smart', 'able', 'know', 'inform', 'TRUE', 'understand', 'clean', 'school', 'feel', 'food', 'learn', 'person', 'smell', 'book']
# ['new', 'statistic', 'grab', 'able', 'hand', 'agree', 'brain', 'inform', 'school', 'know', 'smart', 'data', 'learn', 'comprehend', 'intelligent', 'understand', 'wise', 'experience', 'hold', 'fact']
# ['aware', 'number', 'view', 'able', 'comprehend', 'skill', 'smart', 'brain', 'hold', 'intelligent', 'know', 'experience', 'fact', 'alert', 'learn', 'understand', 'data', 'school', 'inform', 'wise']
#
#
# Based on 10 Megabit ethernet cards which support most kinds of ethernet backbones ( the type of cabling system that is used to connect the network up ) Mainlan is not too difficult to install , although you do really require a basic knowledge of memory configurations in PCs to get the best out of it .
# ['aware', 'word', 'mouth', 'skill', 'protect', 'short', 'language', 'school', 'know', 'able', 'learn', 'feel', 'act', 'food', 'understand', 'person', 'book', 'human', 'inform', 'long']
# ['person', 'aware', 'word', 'mouth', 'smart', 'language', 'able', 'food', 'act', 'understand', 'know', 'short', 'feel', 'long', 'school', 'object', 'care', 'up', 'inform', 'learn']
# ['language', 'book', 'act', 'small', 'feel', 'inform', 'sense', 'able', 'tool', 'smell', 'work', 'grow', 'tree', 'understand', 'learn', 'school', 'green', 'know', 'teach', 'eat']
# ['word', 'love', 'noise', 'act', 'know', 'measure', 'learn', 'feel', 'school', 'eye', 'warm', 'understand', 'see', 'inform', 'able', 'wear', 'person', 'sense', 'book', 'human']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['aware', 'number', 'view', 'able', 'comprehend', 'skill', 'smart', 'brain', 'hold', 'intelligent', 'know', 'experience', 'fact', 'alert', 'learn', 'understand', 'data', 'school', 'inform', 'wise']
#
#
# It is a defence , however , if the defendant can satisfy the court that it was not known or suspected that drug trafficking was involved , or that he disclosed his knowledge or suspicion to the relevant authorities .
# ['aware', 'cook', 'idea', 'mathematics', 'lie', 'measure', 'human', 'act', 'truth', 'know', 'feel', 'object', 'able', 'understand', 'see', 'learn', 'school', 'TRUE', 'inform', 'tell']
# ['high', 'event', 'able', 'truth', 'understand', 'pain', 'move', 'long', 'act', 'object', 'know', 'learn', 'feel', 'TRUE', 'lie', 'human', 'inform', 'noise', 'person', 'school']
# ['bad', 'tell', 'cloth', 'measure', 'able', 'vegetable', 'instrument', 'inform', 'question', 'understand', 'wear', 'music', 'time', 'feel', 'human', 'move', 'act', 'eat', 'know', 'person']
# ['number', 'skill', 'object', 'bad', 'hand', 'sense', 'smart', 'school', 'act', 'able', 'measure', 'know', 'cloth', 'tell', 'understand', 'TRUE', 'lie', 'wear', 'inform', 'new']
# ['new', 'statistic', 'grab', 'able', 'hand', 'agree', 'brain', 'inform', 'school', 'know', 'smart', 'data', 'learn', 'comprehend', 'intelligent', 'understand', 'wise', 'experience', 'hold', 'fact']
# ['aware', 'number', 'view', 'able', 'comprehend', 'skill', 'smart', 'brain', 'hold', 'intelligent', 'know', 'experience', 'fact', 'alert', 'learn', 'understand', 'data', 'school', 'inform', 'wise']
#
#
# The radical instability of the Modernist view of knowledge , whether moral or social , was manifest ; and if Iris Murdoch , among the new novelists , was alone in her capacity as a professional philosopher to counter poor arguments with better , it was equally clear that no one had to be a philosopher to see that the scepticisms of the inter-war years were implausible and ultimately self-contradicting .
# ['ground', 'give', 'study', 'teach', 'book', 'able', 'want', 'high', 'understand', 'communicate', 'inform', 'science', 'smart', 'school', 'person', 'college', 'money', 'learn', 'know', 'feel']
# ['pay', 'value', 'understand', 'instrument', 'learn', 'want', 'science', 'school', 'ground', 'person', 'able', 'high', 'feel', 'study', 'up', 'money', 'know', 'teach', 'college', 'smart']
# ['inform', 'girl', 'see', 'book', 'person', 'science', 'study', 'female', 'know', 'wear', 'music', 'instrument', 'learn', 'smart', 'school', 'teach', 'cloth', 'feel', 'able', 'understand']
# ['inform', 'act', 'clean', 'study', 'smart', 'vegetable', 'measure', 'green', 'able', 'college', 'know', 'number', 'science', 'learn', 'school', 'teach', 'money', 'understand', 'person', 'feel']
# ['number', 'hand', 'new', 'hold', 'able', 'statistic', 'inform', 'agree', 'understand', 'school', 'data', 'learn', 'comprehend', 'brain', 'know', 'intelligent', 'smart', 'experience', 'fact', 'wise']
# ['aware', 'number', 'view', 'able', 'comprehend', 'skill', 'smart', 'brain', 'hold', 'intelligent', 'know', 'experience', 'fact', 'alert', 'learn', 'understand', 'data', 'school', 'inform', 'wise']
#
#
# processing
#
# In August 1990 the sanctions imposed on Iraq as a result of the Gulf crisis triggered a major debt crisis at Goodman International , the Irish conglomerate controlled by Larry Goodman which was Europe 's largest meat processing concern , accounting for around 40 per cent of Ireland 's cattle processing industry .
# ['store', 'work', 'bad', 'crunch', 'part', 'produce', 'large', 'time', 'vegetable', 'create', 'fruit', 'plant', 'green', 'hold', 'place', 'eat', 'sweet', 'grow', 'taste', 'food']
# ['hold', 'create', 'chemical', 'store', 'fruit', 'piece', 'crunch', 'take', 'produce', 'time', 'place', 'plant', 'bad', 'eat', 'green', 'grow', 'sweet', 'work', 'taste', 'food']
# ['sport', 'produce', 'place', 'cook', 'store', 'tree', 'instrument', 'science', 'time', 'plant', 'fruit', 'music', 'green', 'food', 'eat', 'taste', 'hold', 'vegetable', 'grow', 'work']
# ['build', 'create', 'fish', 'produce', 'taste', 'sport', 'hold', 'store', 'eat', 'place', 'mouth', 'work', 'science', 'food', 'plant', 'grow', 'green', 'fruit', 'together', 'tree']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# Firstly , by abandoning the notion that only historians can model and manage data in a way which facilitates their particular data processing aims .
# ['type', 'large', 'part', 'group', 'one', 'make', 'take', 'crime', 'fish', 'wood', 'act', 'boat', 'love', 'build', 'compute', 'instrument', 'way', 'place', 'work', 'create']
# ['center', 'protect', 'type', 'work', 'lead', 'kill', 'fish', 'crime', 'create', 'sweet', 'control', 'show', 'one', 'love', 'compute', 'instrument', 'group', 'boat', 'way', 'band']
# ['idea', 'water', 'day', 'sound', 'word', 'paper', 'mouth', 'create', 'color', 'produce', 'music', 'work', 'part', 'act', 'care', 'write', 'instrument', 'group', 'plan', 'food']
# ['produce', 'move', 'sweet', 'compute', 'red', 'juice', 'create', 'color', 'boat', 'take', 'instrument', 'taste', 'group', 'direct', 'music', 'together', 'way', 'act', 'fruit', 'work']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# Within a single environment it should provide , at the very least , word processing , graphics and composition facilities and , ideally , operate in a consistent manner across all three .
# ['machine', 'add', 'number', 'important', 'vegetable', 'act', 'create', 'game', 'play', 'mathematics', 'hair', 'office', 'study', 'food', 'compute', 'write', 'place', 'science', 'work', 'paper']
# ['art', 'work', 'clean', 'number', 'complete', 'science', 'hair', 'mathematics', 'place', 'act', 'paper', 'vegetable', 'add', 'grow', 'study', 'compute', 'taste', 'write', 'food', 'crunch']
# ['mathematics', 'cloth', 'paper', 'fruit', 'work', 'hair', 'end', 'noise', 'place', 'loud', 'wood', 'grow', 'time', 'write', 'instrument', 'vegetable', 'act', 'eat', 'fly', 'bird']
# ['work', 'cloth', 'machine', 'grow', 'game', 'know', 'create', 'together', 'paper', 'study', 'vegetable', 'mathematics', 'number', 'act', 'science', 'noise', 'loud', 'write', 'sound', 'compute']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# To do this , the tool strips the application of its database , graphical front-end , transaction processing monitor and recompiles it under Micro Focus Cobol .
# ['anger', 'face', 'know', 'act', 'place', 'compute', 'office', 'emotion', 'study', 'bad', 'science', 'crime', 'person', 'area', 'feel', 'part', 'machine', 'complete', 'work', 'food']
# ['order', 'taste', 'crime', 'grow', 'science', 'complete', 'heave', 'bad', 'part', 'machine', 'important', 'area', 'sweet', 'show', 'know', 'face', 'place', 'food', 'compute', 'study']
# ['clean', 'juice', 'string', 'tree', 'cook', 'write', 'kitchen', 'person', 'sweet', 'time', 'paper', 'eat', 'grow', 'work', 'taste', 'fruit', 'green', 'instrument', 'music', 'vegetable']
# ['red', 'machine', 'seed', 'taste', 'feel', 'day', 'tree', 'food', 'mathematics', 'grow', 'juice', 'together', 'music', 'paper', 'create', 'compute', 'number', 'fruit', 'work', 'sweet']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# The image is not digital and so not convenient for automatic processing .
# ['finish', 'mathematics', 'time', 'complete', 'love', 'science', 'tool', 'take', 'move', 'compute', 'make', 'paper', 'food', 'cut', 'together', 'down', 'machine', 'act', 'hold', 'cloth']
# ['mathematics', 'science', 'paper', 'important', 'love', 'together', 'cloth', 'tool', 'act', 'electric', 'make', 'prepare', 'food', 'animal', 'fix', 'hair', 'hold', 'machine', 'compute', 'need']
# ['cook', 'produce', 'metal', 'finish', 'end', 'together', 'animal', 'take', 'paper', 'electric', 'work', 'move', 'man', 'love', 'food', 'hold', 'hair', 'mathematics', 'act', 'time']
# ['machine', 'new', 'see', 'make', 'eye', 'compute', 'electric', 'mix', 'hair', 'take', 'animal', 'move', 'together', 'act', 'car', 'create', 'mathematics', 'produce', 'number', 'food']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# premise
#
# Most critics ' cavils concerned the attempt to shoehorn a plot around Myers ' modest premise .
# ['fur', 'walk', 'hard', 'idea', 'area', 'cloth', 'goal', 'reason', 'soft', 'belief', 'leg', 'TRUE', 'act', 'place', 'small', 'build', 'end', 'write', 'story', 'book']
# ['hard', 'book', 'begin', 'head', 'fur', 'material', 'movie', 'place', 'wood', 'funny', 'leg', 'cloth', 'area', 'TRUE', 'build', 'small', 'write', 'act', 'story', 'end']
# ['water', 'money', 'insect', 'animal', 'house', 'music', 'warm', 'act', 'build', 'hard', 'eat', 'long', 'small', 'leg', 'measure', 'person', 'wear', 'cloth', 'story', 'wood']
# ['create', 'fire', 'hand', 'part', 'small', 'human', 'comfort', 'work', 'sleep', 'end', 'act', 'foot', 'wood', 'leg', 'person', 'story', 'wear', 'cloth', 'write', 'animal']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# It had begun to look as though the Western powers had embraced the premise that no-one kicks a cringing dog .
# ['theory', 'know', 'real', 'woman', 'verb', 'belief', 'science', 'thought', 'think', 'study', 'TRUE', 'idea', 'tell', 'opinion', 'up', 'reason', 'guess', 'work', 'wear', 'story']
# ['theory', 'cold', 'life', 'work', 'way', 'think', 'wear', 'story', 'reason', 'idea', 'science', 'up', 'TRUE', 'tell', 'cook', 'guess', 'opinion', 'belief', 'person', 'thought']
# ['human', 'child', 'guess', 'end', 'play', 'chemical', 'place', 'face', 'tell', 'ask', 'thought', 'water', 'belief', 'science', 'story', 'wear', 'think', 'know', 'cloth', 'idea']
# ['body', 'cook', 'piece', 'build', 'thought', 'guess', 'TRUE', 'part', 'person', 'science', 'money', 'wear', 'story', 'metal', 'belief', 'think', 'cloth', 'hand', 'idea', 'know']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# So we 've come the premise .
# ['earth', 'life', 'green', 'up', 'thought', 'house', 'explain', 'begin', 'goal', 'wear', 'end', 'build', 'reason', 'science', 'happen', 'belief', 'TRUE', 'real', 'idea', 'tell']
# ['explain', 'land', 'goal', 'warm', 'cook', 'emotion', 'house', 'build', 'TRUE', 'begin', 'end', 'food', 'life', 'green', 'wear', 'belief', 'science', 'real', 'idea', 'reason']
# ['close', 'protect', 'time', 'lie', 'real', 'answer', 'ocean', 'door', 'belief', 'number', 'measure', 'land', 'end', 'TRUE', 'green', 'water', 'wear', 'vegetable', 'eat', 'fish']
# ['wrong', 'warm', 'know', 'house', 'answer', 'cloth', 'swim', 'large', 'idea', 'hand', 'long', 'feel', 'build', 'end', 'TRUE', 'water', 'fish', 'wood', 'store', 'wear']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['idea', 'fight', 'up', 'bring', 'think', 'top', 'high', 'act', 'person', 'effect', 'result', 'choice', 'happen', 'point', 'decide', 'final', 'close', 'finish', 'thought', 'end']
#
#
# The proposals , based on the premise that " cosmopolitan " laws put French people at a disadvantage , effectively placed immigrants in a separate category of those who could not be joined by their families and should not be eligible for certain benefits , while French people would take priority for jobs and housing .
# ['feel', 'area', 'science', 'land', 'reason', 'know', 'verb', 'two', 'thought', 'write', 'opinion', 'group', 'think', 'person', 'TRUE', 'belief', 'idea', 'human', 'small', 'guess']
# ['object', 'two', 'land', 'area', 'metal', 'sharp', 'human', 'group', 'guess', 'idea', 'small', 'know', 'person', 'cook', 'thought', 'belief', 'think', 'opinion', 'reason', 'TRUE']
# ['work', 'story', 'science', 'ask', 'taste', 'sweet', 'guess', 'tool', 'number', 'wood', 'idea', 'know', 'belief', 'green', 'group', 'person', 'wear', 'small', 'mathematics', 'think']
# ['two', 'help', 'metal', 'grow', 'work', 'TRUE', 'person', 'communicate', 'money', 'body', 'water', 'think', 'end', 'human', 'belief', 'opinion', 'thought', 'hand', 'idea', 'know']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# The division of the psychical into what is conscious and what is unconscious is the fundamental premise of psychoanalysis ; … psychoanalysis can not situate the essence of the psychical in consciousness , but is obliged to regard consciousness as a quality of the psychical , which may be present in addition to other qualities or may be absent .
# ['moral', 'belief', 'part', 'fast', 'mean', 'reason', 'religion', 'person', 'area', 'store', 'idea', 'goal', 'science', 'TRUE', 'point', 'church', 'god', 'hunt', 'end', 'know']
# ['point', 'theory', 'mammal', 'scare', 'story', 'church', 'mean', 'religion', 'TRUE', 'part', 'area', 'goal', 'reason', 'belief', 'god', 'idea', 'end', 'fast', 'life', 'store']
# ['two', 'brown', 'story', 'shape', 'fast', 'god', 'hold', 'lie', 'day', 'anger', 'feel', 'animal', 'know', 'hand', 'part', 'TRUE', 'person', 'large', 'belief', 'idea']
# ['name', 'belief', 'idea', 'animal', 'color', 'car', 'person', 'end', 'agree', 'know', 'right', 'part', 'finish', 'light', 'science', 'water', 'noise', 'store', 'TRUE', 'group']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# concept
#
# It was what we said for convenience ; there was no concept in Egypt of unmarried couples .
# ['eye', 'inform', 'verb', 'sharp', 'hold', 'human', 'direct', 'understand', 'know', 'hand', 'idea', 'word', 'person', 'object', 'communicate', 'create', 'thought', 'act', 'express', 'physic']
# ['scare', 'express', 'aware', 'move', 'communicate', 'eye', 'intent', 'see', 'create', 'word', 'hand', 'idea', 'object', 'direct', 'person', 'thought', 'human', 'know', 'act', 'understand']
# ['hunt', 'thought', 'four', 'house', 'kill', 'smell', 'way', 'act', 'paper', 'number', 'know', 'story', 'store', 'idea', 'fire', 'large', 'person', 'move', 'animal', 'place']
# ['normal', 'thought', 'see', 'move', 'close', 'think', 'end', 'car', 'water', 'play', 'know', 'act', 'idea', 'music', 'wood', 'large', 'store', 'person', 'group', 'human']
# ['advice', 'prove', 'guess', 'define', 'hypothesis', 'word', 'light', 'bulb', 'brain', 'find', 'science', 'theory', 'explain', 'abstract', 'plan', 'idea', 'thought', 'diction', 'mean', 'think']
# ['walk', 'look', 'guess', 'plan', 'sentence', 'explain', 'abstract', 'word', 'diction', 'move', 'theory', 'act', 'science', 'mean', 'see', 'human', 'think', 'thought', 'idea', 'person']
#
#
# So is the Vendobionta concept completely redundant ?
# ['guess', 'together', 'wood', 'look', 'work', 'group', 'eye', 'part', 'food', 'long', 'theory', 'small', 'plan', 'word', 'human', 'piece', 'thought', 'science', 'idea', 'person']
# ['communicate', 'color', 'guess', 'word', 'away', 'run', 'part', 'plan', 'eye', 'theory', 'small', 'object', 'thought', 'idea', 'human', 'science', 'person', 'long', 'piece', 'wood']
# ['think', 'plan', 'long', 'fire', 'part', 'idea', 'move', 'science', 'car', 'house', 'act', 'word', 'measure', 'leg', 'story', 'wear', 'cloth', 'store', 'write', 'ask']
# ['metal', 'beak', 'agree', 'win', 'plan', 'act', 'food', 'move', 'bird', 'build', 'wear', 'fire', 'human', 'happy', 'part', 'weapon', 'idea', 'color', 'feather', 'cloth']
# ['life', 'equate', 'sight', 'mean', 'eye', 'light', 'abstract', 'think', 'bulb', 'plan', 'best', 'brain', 'see', 'perfect', 'recipe', 'idea', 'mathematics', 'thought', 'belief', 'theory']
# ['walk', 'look', 'guess', 'plan', 'sentence', 'explain', 'abstract', 'word', 'diction', 'move', 'theory', 'act', 'science', 'mean', 'see', 'human', 'think', 'thought', 'idea', 'person']
#
#
# Ms Bueno , who won 20 Grand Slam titles in an on-court career abruptly curtailed through injury in the late sixties , commented today : ‘ Tennis Interlink is an exciting new concept which will enhance our sport at many levels .
# ['mammal', 'hair', 'four', 'leg', 'animal', 'together', 'idea', 'hand', 'way', 'two', 'know', 'thought', 'human', 'new', 'person', 'act', 'think', 'one', 'goal', 'plan']
# ['verb', 'intent', 'communicate', 'new', 'plan', 'leg', 'act', 'understand', 'way', 'thought', 'piece', 'direct', 'person', 'help', 'know', 'idea', 'hand', 'come', 'human', 'goal']
# ['think', 'number', 'road', 'ask', 'love', 'plan', 'want', 'grow', 'create', 'hold', 'one', 'animal', 'walk', 'goal', 'know', 'move', 'person', 'idea', 'way', 'act']
# ['ask', 'name', 'love', 'happy', 'smell', 'act', 'plan', 'kitchen', 'build', 'want', 'idea', 'food', 'arm', 'child', 'human', 'hand', 'part', 'clean', 'cook', 'body']
# ['life', 'equate', 'sight', 'mean', 'eye', 'light', 'abstract', 'think', 'bulb', 'plan', 'best', 'brain', 'see', 'perfect', 'recipe', 'idea', 'mathematics', 'thought', 'belief', 'theory']
# ['walk', 'look', 'guess', 'plan', 'sentence', 'explain', 'abstract', 'word', 'diction', 'move', 'theory', 'act', 'science', 'mean', 'see', 'human', 'think', 'thought', 'idea', 'person']
#
#
# In Coldunell Ltd. v. Gallon , as with the other recent authorities , I believe that the results , if not all the specific ratios decidendi , can be reconciled if this equitable principle is observed , and the artificial concept of agency is abandoned in all cases save those where contractual or ostensible agency is clearly established .
# ['part', 'communicate', 'male', 'express', 'create', 'hold', 'eye', 'understand', 'verb', 'theory', 'metal', 'hand', 'thought', 'object', 'know', 'person', 'human', 'feel', 'idea', 'word']
# ['body', 'noise', 'communicate', 'aware', 'act', 'verb', 'part', 'theory', 'male', 'understand', 'word', 'human', 'feel', 'thought', 'person', 'idea', 'hand', 'hold', 'know', 'object']
# ['sense', 'protect', 'person', 'noise', 'human', 'warm', 'object', 'taste', 'thought', 'think', 'wear', 'sweet', 'hand', 'small', 'metal', 'act', 'idea', 'know', 'house', 'smell']
# ['noise', 'thought', 'water', 'grow', 'word', 'object', 'think', 'green', 'person', 'animal', 'act', 'feel', 'know', 'hand', 'body', 'hold', 'idea', 'human', 'metal', 'eat']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['walk', 'look', 'guess', 'plan', 'sentence', 'explain', 'abstract', 'word', 'diction', 'move', 'theory', 'act', 'science', 'mean', 'see', 'human', 'think', 'thought', 'idea', 'person']
#
#
# Concept one should have an idea for a workable product
# ['mathematics', 'wood', 'one', 'sharp', 'human', 'build', 'love', 'car', 'plan', 'small', 'food', 'act', 'hand', 'know', 'think', 'part', 'idea', 'person', 'thought', 'object']
# ['know', 'car', 'feel', 'thought', 'fish', 'green', 'love', 'movie', 'food', 'wood', 'water', 'think', 'part', 'sharp', 'hand', 'object', 'human', 'person', 'idea', 'act']
# ['wood', 'thought', 'see', 'house', 'car', 'fish', 'bird', 'know', 'think', 'hold', 'act', 'person', 'group', 'fruit', 'sweet', 'tree', 'music', 'water', 'idea', 'build']
# ['word', 'build', 'question', 'feather', 'think', 'swim', 'fish', 'part', 'idea', 'vegetable', 'human', 'money', 'know', 'act', 'eat', 'grow', 'water', 'green', 'person', 'bird']
# ['life', 'equate', 'sight', 'mean', 'eye', 'light', 'abstract', 'think', 'bulb', 'plan', 'best', 'brain', 'see', 'perfect', 'recipe', 'idea', 'mathematics', 'thought', 'belief', 'theory']
# ['walk', 'look', 'guess', 'plan', 'sentence', 'explain', 'abstract', 'word', 'diction', 'move', 'theory', 'act', 'science', 'mean', 'see', 'human', 'think', 'thought', 'idea', 'person']
#
#
# constituency
#
# That left the way open for the excellent constituency MP to make his peace with the leadership of the party which may , at last , be on the rise .
# ['vote', 'large', 'elect', 'family', 'office', 'tree', 'politics', 'city', 'small', 'place', 'govern', 'person', 'group', 'land', 'house', 'town', 'state', 'area', 'part', 'wood']
# ['smell', 'tree', 'vote', 'wood', 'close', 'elect', 'office', 'land', 'place', 'person', 'city', 'part', 'house', 'govern', 'politics', 'small', 'town', 'area', 'group', 'food']
# ['office', 'sweet', 'close', 'part', 'hold', 'politics', 'crime', 'town', 'house', 'fruit', 'state', 'taste', 'law', 'group', 'area', 'person', 'small', 'govern', 'city', 'place']
# ['store', 'sweet', 'year', 'place', 'group', 'area', 'town', 'govern', 'person', 'part', 'ask', 'time', 'house', 'small', 'color', 'law', 'wood', 'politics', 'day', 'city']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# CONCLUSION — bilingual awareness for a wider constituency
# ['communicate', 'area', 'person', 'animal', 'one', 'large', 'house', 'object', 'long', 'number', 'human', 'eat', 'group', 'sharp', 'place', 'body', 'wood', 'know', 'act', 'small']
# ['hot', 'emotion', 'movie', 'small', 'house', 'love', 'number', 'wood', 'sharp', 'person', 'human', 'object', 'time', 'animal', 'body', 'eat', 'group', 'area', 'act', 'long']
# ['love', 'fire', 'four', 'color', 'point', 'comfort', 'long', 'word', 'soft', 'one', 'leg', 'person', 'time', 'together', 'animal', 'area', 'number', 'sharp', 'group', 'cut']
# ['fire', 'money', 'eye', 'metal', 'word', 'time', 'work', 'color', 'small', 'number', 'group', 'sharp', 'person', 'wood', 'eat', 'love', 'kill', 'animal', 'cut', 'water']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# The only place peaceful enough in the midst of an economic crisis , it seemed , was his early Victorian former vicarage home at Stoney Stanton , in his constituency , two-and-a-half hours ' drive away .
# ['art', 'represent', 'space', 'town', 'elect', 'vote', 'small', 'rule', 'govern', 'person', 'place', 'law', 'part', 'city', 'area', 'house', 'politics', 'group', 'office', 'state']
# ['space', 'law', 'vote', 'place', 'elect', 'govern', 'office', 'politics', 'person', 'animal', 'state', 'house', 'love', 'small', 'wood', 'land', 'area', 'taste', 'art', 'city']
# ['office', 'soft', 'leg', 'rule', 'area', 'win', 'measure', 'state', 'person', 'group', 'city', 'place', 'house', 'cloth', 'wear', 'small', 'day', 'politics', 'govern', 'law']
# ['measure', 'part', 'sharp', 'leg', 'person', 'wood', 'area', 'state', 'paper', 'animal', 'govern', 'place', 'small', 'city', 'law', 'group', 'day', 'politics', 'house', 'drink']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# Within the coterminous Borough and Parliamentary Constituency of Blyth Valley , the old Labour hegemony based on the coal field has been seriously threatened by the emergence of an Alliance challenge .
# ['picture', 'represent', 'food', 'seat', 'law', 'vote', 'city', 'elect', 'office', 'hold', 'person', 'politics', 'govern', 'eat', 'group', 'place', 'small', 'part', 'area', 'house']
# ['loud', 'house', 'bad', 'taste', 'name', 'vote', 'soft', 'food', 'hold', 'office', 'group', 'elect', 'place', 'eat', 'part', 'small', 'politics', 'area', 'person', 'govern']
# ['soft', 'point', 'hunt', 'sharp', 'house', 'state', 'fly', 'comfort', 'part', 'govern', 'city', 'law', 'politics', 'area', 'person', 'bird', 'place', 'small', 'group', 'large']
# ['vote', 'church', 'govern', 'area', 'state', 'piece', 'paper', 'law', 'place', 'small', 'person', 'meat', 'politics', 'day', 'name', 'money', 'group', 'office', 'city', 'part']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# We are left with real problems of unemployment and all that goes with that with the drifting away of hospital care so that everything is centered outside the constituency ; with the drifting away of real jobs so that people have to move outside .
# ['land', 'belief', 'rule', 'hold', 'elect', 'state', 'group', 'office', 'town', 'part', 'politics', 'love', 'vote', 'body', 'small', 'law', 'area', 'person', 'govern', 'city']
# ['space', 'art', 'town', 'eat', 'land', 'goal', 'love', 'part', 'city', 'elect', 'state', 'group', 'office', 'small', 'govern', 'area', 'body', 'person', 'politics', 'vote']
# ['see', 'love', 'part', 'soft', 'own', 'office', 'city', 'sharp', 'person', 'house', 'group', 'country', 'state', 'small', 'law', 'cut', 'area', 'govern', 'body', 'politics']
# ['four', 'animal', 'law', 'body', 'small', 'area', 'large', 'space', 'govern', 'state', 'leg', 'person', 'group', 'politics', 'time', 'day', 'town', 'color', 'city', 'part']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# historian
#
# In the 1960s he gave up practice to pursue an academic career as an architectural historian .
# ['law', 'take', 'dead', 'know', 'beak', 'feather', 'govern', 'animal', 'bird', 'fly', 'pass', 'office', 'wing', 'study', 'event', 'new', 'time', 'book', 'person', 'work']
# ['write', 'hold', 'story', 'help', 'inform', 'office', 'know', 'time', 'pass', 'bird', 'wing', 'lay', 'see', 'new', 'book', 'take', 'person', 'work', 'event', 'study']
# ['create', 'instrument', 'build', 'beak', 'body', 'work', 'write', 'smell', 'hand', 'person', 'one', 'music', 'water', 'book', 'country', 'story', 'eat', 'hold', 'bird', 'science']
# ['part', 'new', 'store', 'taste', 'build', 'large', 'write', 'story', 'fish', 'person', 'study', 'time', 'swim', 'eat', 'water', 'science', 'animal', 'book', 'create', 'work']
# ['learn', 'law', 'subject', 'vote', 'experiment', 'republic', 'democracy', 'biology', 'person', 'school', 'president', 'chemical', 'study', 'happen', 'govern', 'time', 'event', 'pass', 'record', 'story']
# ['tradition', 'study', 'vote', 'history', 'legend', 'fiction', 'god', 'event', 'down', 'tale', 'pass', 'story', 'govern', 'culture', 'myth', 'belief', 'generate', 'ritual', 'person', 'family']
#
#
# Thus entries for , say , the year 1680 will not end at 31 December but continue through January , February and most of March 1681 ; sometimes they will be written as 1680/1 for the period between 1 January and 25 March , and it is as well for the local and family historian to adopt that convention or else he will get in a hopeless muddle .
# ['create', 'life', 'happen', 'science', 'lead', 'inform', 'know', 'dead', 'event', 'book', 'new', 'story', 'person', 'work', 'one', 'study', 'pass', 'time', 'write', 'old']
# ['lay', 'egg', 'wing', 'fly', 'study', 'foot', 'science', 'new', 'happen', 'know', 'time', 'inform', 'story', 'one', 'pass', 'old', 'event', 'book', 'work', 'person']
# ['music', 'fly', 'pass', 'clean', 'create', 'cook', 'drink', 'word', 'know', 'story', 'work', 'one', 'science', 'person', 'bird', 'write', 'body', 'book', 'time', 'smell']
# ['old', 'fire', 'new', 'smell', 'law', 'time', 'feather', 'write', 'foot', 'pass', 'science', 'book', 'wing', 'fly', 'hot', 'store', 'story', 'person', 'bird', 'beak']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['tradition', 'study', 'vote', 'history', 'legend', 'fiction', 'god', 'event', 'down', 'tale', 'pass', 'story', 'govern', 'culture', 'myth', 'belief', 'generate', 'ritual', 'person', 'family']
#
#
# For example , in asking why the French did not innovate like the British , one historian turns straight to economic factors .
# ['live', 'experience', 'science', 'record', 'law', 'dead', 'happen', 'old', 'study', 'one', 'event', 'pass', 'work', 'story', 'state', 'day', 'give', 'book', 'time', 'person']
# ['new', 'measure', 'lead', 'story', 'know', 'inform', 'book', 'record', 'work', 'state', 'experience', 'time', 'event', 'person', 'give', 'one', 'day', 'happen', 'old', 'pass']
# ['music', 'one', 'law', 'science', 'write', 'measure', 'story', 'pass', 'work', 'wing', 'country', 'day', 'smell', 'bird', 'book', 'time', 'person', 'beak', 'feather', 'fly']
# ['cold', 'beak', 'same', 'old', 'know', 'fly', 'protect', 'foot', 'feather', 'work', 'story', 'hot', 'law', 'book', 'bird', 'store', 'time', 'pass', 'person', 'cook']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['tradition', 'study', 'vote', 'history', 'legend', 'fiction', 'god', 'event', 'down', 'tale', 'pass', 'story', 'govern', 'culture', 'myth', 'belief', 'generate', 'ritual', 'person', 'family']
#
#
# When a city rules an empire , a historian with any curiosity will ask whether the imperial city was specially geographically favoured from the first .
# ['school', 'know', 'one', 'experience', 'person', 'event', 'dead', 'inform', 'new', 'old', 'book', 'write', 'science', 'time', 'paper', 'pass', 'study', 'work', 'law', 'story']
# ['law', 'science', 'animal', 'dead', 'new', 'record', 'paper', 'book', 'know', 'person', 'time', 'study', 'old', 'experience', 'inform', 'pass', 'story', 'event', 'write', 'work']
# ['fly', 'old', 'bird', 'dead', 'paper', 'school', 'know', 'story', 'book', 'work', 'science', 'music', 'study', 'law', 'time', 'store', 'write', 'body', 'word', 'person']
# ['create', 'military', 'money', 'pass', 'day', 'store', 'story', 'person', 'know', 'time', 'work', 'book', 'school', 'law', 'word', 'animal', 'write', 'bird', 'paper', 'new']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# According to the historian J. H. Plumb , both George I and George II were " crassly stupid " and " incapable , totally incapable , of forming a policy . "
# ['study', 'bird', 'know', 'wing', 'wear', 'inform', 'see', 'body', 'new', 'dead', 'time', 'pass', 'story', 'work', 'one', 'old', 'event', 'person', 'book', 'break']
# ['dead', 'cloth', 'science', 'watch', 'know', 'work', 'two', 'new', 'inform', 'story', 'old', 'lead', 'event', 'time', 'book', 'person', 'body', 'pass', 'break', 'one']
# ['beak', 'feather', 'fly', 'instrument', 'study', 'create', 'new', 'country', 'work', 'story', 'science', 'bird', 'book', 'music', 'person', 'wear', 'one', 'body', 'write', 'cloth']
# ['school', 'study', 'hot', 'water', 'same', 'warm', 'beak', 'know', 'feather', 'write', 'foot', 'story', 'bird', 'book', 'person', 'build', 'body', 'animal', 'eat', 'wear']
# ['rank', 'work', 'lab', 'smart', 'special', 'military', 'area', 'skill', 'profess', 'field', 'experience', 'law', 'know', 'police', 'authority', 'person', 'science', 'experiment', 'specific', 'chemical']
# ['tradition', 'study', 'vote', 'history', 'legend', 'fiction', 'god', 'event', 'down', 'tale', 'pass', 'story', 'govern', 'culture', 'myth', 'belief', 'generate', 'ritual', 'person', 'family']
#
#
# victory
#
# The Federation for Ulster Local Studies hailed the decision as an ‘ historic victory ’ — but the Post Office warned it was a ‘ backward step ’ which could hit local mail deliveries .
# ['best', 'place', 'move', 'fly', 'goal', 'event', 'opposite', 'victor', 'take', 'compete', 'lose', 'end', 'happy', 'person', 'come', 'success', 'accomplish', 'win', 'achieve', 'good']
# ['good', 'lead', 'compete', 'person', 'event', 'goal', 'achieve', 'victor', 'happy', 'end', 'lose', 'accomplish', 'direct', 'politics', 'opposite', 'black', 'best', 'come', 'success', 'win']
# ['victor', 'time', 'able', 'swim', 'come', 'politics', 'take', 'finish', 'lose', 'accomplish', 'success', 'govern', 'goal', 'compete', 'win', 'person', 'happy', 'achieve', 'good', 'end']
# ['victor', 'paper', 'taste', 'lose', 'name', 'win', 'bird', 'feather', 'end', 'beak', 'good', 'achieve', 'come', 'success', 'compete', 'accomplish', 'person', 'fly', 'happy', 'eat']
# ['goal', 'achieve', 'first', 'name', 'beat', 'champion', 'happy', 'one', 'victor', 'compete', 'contest', 'person', 'come', 'accomplish', 'lose', 'success', 'win', 'feel', 'best', 'defeat']
# ['champion', 'prize', 'one', 'happy', 'first', 'beat', 'feel', 'contest', 'goal', 'person', 'compete', 'come', 'defeat', 'achieve', 'lose', 'best', 'accomplish', 'victor', 'success', 'win']
#
#
# Election 1992 : Tory ‘ super-party ’ born out of last-minute vote switching The Conservative victory was a surprise .
# ['goal', 'best', 'accomplish', 'person', 'over', 'win', 'feel', 'success', 'happy', 'elect', 'politics', 'victor', 'prize', 'govern', 'achieve', 'come', 'lose', 'compete', 'place', 'vote']
# ['office', 'over', 'come', 'happy', 'compete', 'victor', 'prize', 'elect', 'govern', 'vote', 'success', 'accomplish', 'run', 'achieve', 'lose', 'person', 'politics', 'best', 'win', 'place']
# ['happy', 'politics', 'gold', 'goal', 'success', 'water', 'govern', 'time', 'run', 'achieve', 'good', 'wear', 'take', 'number', 'lose', 'compete', 'person', 'come', 'win', 'end']
# ['victor', 'dead', 'wing', 'come', 'lose', 'compete', 'fight', 'success', 'school', 'accomplish', 'person', 'happy', 'achieve', 'run', 'fly', 'bird', 'end', 'good', 'win', 'water']
# ['vote', 'person', 'one', 'most', 'large', 'beat', 'group', 'number', 'contest', 'great', 'compete', 'lose', 'defeat', 'best', 'success', 'accomplish', 'feel', 'come', 'victor', 'win']
# ['champion', 'prize', 'one', 'happy', 'first', 'beat', 'feel', 'contest', 'goal', 'person', 'compete', 'come', 'defeat', 'achieve', 'lose', 'best', 'accomplish', 'victor', 'success', 'win']
#
#
# … victory hopes
# ['life', 'hard', 'live', 'god', 'sport', 'time', 'dead', 'drink', 'accomplish', 'feel', 'win', 'end', 'act', 'person', 'achieve', 'success', 'happy', 'goal', 'come', 'game']
# ['live', 'hard', 'football', 'think', 'place', 'game', 'god', 'give', 'end', 'feel', 'point', 'goal', 'accomplish', 'act', 'come', 'happy', 'success', 'achieve', 'win', 'sport']
# ['happy', 'mouth', 'god', 'insect', 'lead', 'compete', 'govern', 'come', 'sport', 'place', 'take', 'good', 'car', 'give', 'wear', 'game', 'end', 'win', 'food', 'time']
# ['come', 'compete', 'day', 'fight', 'know', 'game', 'number', 'door', 'wheel', 'swim', 'fish', 'good', 'end', 'happy', 'win', 'sport', 'person', 'water', 'place', 'car']
# ...
#
#
# Turning well inside the box he side-stepped Birney to hammer in a shot which McConnell did well to push out for a corner .
# ['write', 'ground', 'food', 'ball', 'wood', 'hard', 'plastic', 'contain', 'paper', 'carry', 'thing', 'game', 'round', 'hold', 'play', 'store', 'white', 'object', 'sport', 'small']
# ['good', 'contain', 'write', 'plastic', 'carry', 'object', 'four', 'ball', 'organize', 'paper', 'wood', 'store', 'thing', 'small', 'round', 'play', 'white', 'hold', 'sport', 'game']
# ['water', 'animal', 'four', 'time', 'small', 'carry', 'contain', 'round', 'plastic', 'ball', 'metal', 'hold', 'sport', 'door', 'store', 'wood', 'play', 'paper', 'thing', 'game']
# ['four', 'leg', 'ball', 'object', 'place', 'carry', 'bird', 'small', 'hold', 'round', 'eat', 'store', 'wood', 'metal', 'thing', 'sport', 'door', 'play', 'game', 'hand']
# ['hollow', 'edge', 'object', 'six', 'lid', 'size', 'large', 'four', 'corner', 'angle', 'small', 'store', 'thing', 'move', 'three', 'hold', 'contain', 'side', 'square', 'cardboard']
# ['wood', 'plastic', 'object', 'small', 'size', 'corner', 'angle', 'six', 'large', 'four', 'contain', 'square', 'thing', 'side', 'move', 'store', 'hold', 'lid', 'cardboard', 'three']
#
#
# He knew of course that he never could meet them , but he wanted so badly to talk to them that he would get out their letters and pictures from his box of papers and talk quietly to them anyway .
# ['shape', 'money', 'color', 'liquid', 'animal', 'wood', 'organize', 'hand', 'round', 'plastic', 'contain', 'thing', 'carry', 'place', 'metal', 'small', 'store', 'hold', 'paper', 'large']
# ['shape', 'organize', 'round', 'item', 'animal', 'money', 'wood', 'paper', 'carry', 'plastic', 'hold', 'metal', 'large', 'small', 'place', 'thing', 'contain', 'break', 'liquid', 'store']
# ['bag', 'animal', 'group', 'contain', 'kitchen', 'day', 'round', 'metal', 'money', 'glass', 'plastic', 'paper', 'hold', 'carry', 'wood', 'thing', 'small', 'hand', 'store', 'large']
# ['work', 'glass', 'wheel', 'small', 'place', 'instrument', 'book', 'round', 'contain', 'plastic', 'paper', 'hand', 'store', 'carry', 'large', 'wood', 'money', 'thing', 'music', 'hold']
# ['hollow', 'edge', 'six', 'size', 'object', 'angle', 'four', 'large', 'corner', 'lid', 'cardboard', 'square', 'side', 'move', 'three', 'store', 'hold', 'small', 'contain', 'thing']
# ['wood', 'plastic', 'object', 'small', 'size', 'corner', 'angle', 'six', 'large', 'four', 'contain', 'square', 'thing', 'side', 'move', 'store', 'hold', 'lid', 'cardboard', 'three']
#
#
# Few things earned more pleasant congratulation than abstinence : " No thank you , " to a second chocolate , and Maman 's face lighted gently as she snapped the lid back on the choc box before Nicandra could change her mind .
# ['animal', 'four', 'top', 'white', 'object', 'hand', 'color', 'good', 'eat', 'metal', 'paper', 'store', 'plastic', 'contain', 'hold', 'carry', 'thing', 'food', 'small', 'round']
# ['object', 'hand', 'woman', 'animal', 'good', 'top', 'white', 'store', 'metal', 'contain', 'small', 'plastic', 'hold', 'paper', 'thing', 'color', 'carry', 'food', 'eat', 'round']
# ['play', 'large', 'round', 'small', 'four', 'kitchen', 'animal', 'contain', 'hand', 'plastic', 'store', 'glass', 'wood', 'metal', 'hold', 'thing', 'carry', 'food', 'door', 'paper']
# ['wood', 'wheel', 'fruit', 'paper', 'kitchen', 'plastic', 'round', 'glass', 'metal', 'contain', 'hand', 'color', 'carry', 'hold', 'small', 'food', 'taste', 'thing', 'eat', 'store']
# ['hollow', 'edge', 'six', 'size', 'object', 'angle', 'four', 'large', 'corner', 'lid', 'cardboard', 'square', 'side', 'move', 'three', 'store', 'hold', 'small', 'contain', 'thing']
# ['wood', 'plastic', 'object', 'small', 'size', 'corner', 'angle', 'six', 'large', 'four', 'contain', 'square', 'thing', 'side', 'move', 'store', 'hold', 'lid', 'cardboard', 'three']
#
#
# train
#
# It was 5.33 when he rang through the ‘ train in section ’ and 5.48 when he put the signal to green and heard the train start up .
# ['loud', 'cargo', 'human', 'pull', 'engine', 'object', 'ride', 'car', 'wheel', 'person', 'large', 'travel', 'passage', 'fast', 'metal', 'transport', 'drive', 'vehicle', 'move', 'carry']
# ['human', 'passage', 'object', 'metal', 'ride', 'pull', 'travel', 'move', 'loud', 'engine', 'car', 'carry', 'cargo', 'large', 'vehicle', 'transport', 'drive', 'fast', 'person', 'wheel']
# ['group', 'money', 'metal', 'water', 'two', 'carry', 'drive', 'passage', 'human', 'fast', 'person', 'move', 'engine', 'loud', 'fly', 'large', 'car', 'vehicle', 'transport', 'wheel']
# ['pull', 'door', 'horse', 'engine', 'wing', 'four', 'two', 'loud', 'human', 'drive', 'transport', 'wheel', 'vehicle', 'carry', 'fast', 'move', 'bird', 'car', 'passage', 'fly']
# ['choo', 'railroad', 'conduct', 'coal', 'electric', 'human', 'run', 'car', 'engine', 'carry', 'cargo', 'track', 'transport', 'many', 'caboose', 'wheel', 'fast', 'freight', 'rail', 'passage']
# ['conduct', 'electric', 'move', 'vehicle', 'run', 'carry', 'many', 'car', 'human', 'drive', 'cargo', 'caboose', 'fast', 'rail', 'freight', 'wheel', 'transport', 'engine', 'passage', 'track']
#
#
# The motion of the train , the clickety-click of the rail joints , had a somewhat soporific effect on Mr Wishart and he found himself nodding off .
# ['four', 'ride', 'engine', 'loud', 'passage', 'object', 'carry', 'drive', 'fast', 'human', 'long', 'car', 'travel', 'wheel', 'move', 'person', 'large', 'transport', 'vehicle', 'metal']
# ['engine', 'ride', 'noise', 'vehicle', 'transport', 'cargo', 'carry', 'metal', 'passage', 'large', 'object', 'person', 'fast', 'move', 'car', 'long', 'drive', 'loud', 'wheel', 'travel']
# ['travel', 'yellow', 'engine', 'noise', 'human', 'move', 'fast', 'money', 'passage', 'loud', 'person', 'car', 'carry', 'drive', 'vehicle', 'large', 'transport', 'fly', 'two', 'wheel']
# ['long', 'carry', 'loud', 'water', 'two', 'leg', 'passage', 'person', 'fast', 'wheel', 'eat', 'vehicle', 'move', 'transport', 'fly', 'drive', 'car', 'bird', 'four', 'large']
# ['railroad', 'run', 'electric', 'coal', 'choo', 'conduct', 'car', 'passage', 'track', 'engine', 'carry', 'cargo', 'many', 'transport', 'human', 'rail', 'freight', 'fast', 'caboose', 'wheel']
# ['conduct', 'electric', 'move', 'vehicle', 'run', 'carry', 'many', 'car', 'human', 'drive', 'cargo', 'caboose', 'fast', 'rail', 'freight', 'wheel', 'transport', 'engine', 'passage', 'track']
#
#
# However , in late 1986 a challenge emerged to the predominant pattern of unionization in the shape of a new grade-based union , the Sindicato Español de Maquinistas y Ayudantes Ferroviarios ( SEMAF — Spanish Union of Train Drivers and Drivers ' Assistants ) .
# ['hand', 'vehicle', 'fast', 'drive', 'person', 'hold', 'car', 'large', 'carry', 'passage', 'wheel', 'work', 'object', 'act', 'loud', 'long', 'human', 'transport', 'move', 'metal']
# ['noise', 'drive', 'engine', 'act', 'pull', 'long', 'work', 'human', 'large', 'vehicle', 'passage', 'person', 'loud', 'fast', 'car', 'carry', 'object', 'transport', 'move', 'metal']
# ['hot', 'work', 'move', 'school', 'fast', 'fly', 'transport', 'vehicle', 'bird', 'metal', 'passage', 'wing', 'place', 'water', 'long', 'drive', 'wheel', 'boat', 'car', 'carry']
# ['animal', 'clean', 'hand', 'drive', 'object', 'passage', 'fast', 'day', 'human', 'water', 'fly', 'eat', 'vehicle', 'metal', 'act', 'wheel', 'work', 'move', 'transport', 'car']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['conduct', 'electric', 'move', 'vehicle', 'run', 'carry', 'many', 'car', 'human', 'drive', 'cargo', 'caboose', 'fast', 'rail', 'freight', 'wheel', 'transport', 'engine', 'passage', 'track']
#
#
# I did n't go into the parents ' room but went on beyond it to find myself in the rear part of the carriage , at the very end of the train .
# ['long', 'cargo', 'pull', 'engine', 'loud', 'metal', 'passage', 'move', 'wheel', 'car', 'travel', 'object', 'human', 'carry', 'vehicle', 'large', 'transport', 'person', 'drive', 'fast']
# ['long', 'engine', 'cargo', 'pull', 'human', 'move', 'loud', 'large', 'carry', 'passage', 'fast', 'metal', 'wheel', 'travel', 'vehicle', 'person', 'transport', 'car', 'object', 'drive']
# ['two', 'music', 'carry', 'engine', 'money', 'travel', 'large', 'car', 'water', 'drive', 'passage', 'metal', 'fly', 'transport', 'vehicle', 'move', 'fast', 'loud', 'wheel', 'human']
# ['horse', 'engine', 'two', 'fly', 'hand', 'human', 'loud', 'person', 'four', 'carry', 'transport', 'drive', 'vehicle', 'fast', 'move', 'wheel', 'large', 'car', 'metal', 'passage']
# ['railroad', 'run', 'electric', 'coal', 'choo', 'conduct', 'car', 'passage', 'track', 'engine', 'carry', 'cargo', 'many', 'transport', 'human', 'rail', 'freight', 'fast', 'caboose', 'wheel']
# ['conduct', 'electric', 'move', 'vehicle', 'run', 'carry', 'many', 'car', 'human', 'drive', 'cargo', 'caboose', 'fast', 'rail', 'freight', 'wheel', 'transport', 'engine', 'passage', 'track']
#
#
# On the second Saturday they took the train to London .
# ['long', 'ride', 'pull', 'cargo', 'drive', 'car', 'large', 'object', 'wheel', 'person', 'move', 'travel', 'human', 'transport', 'vehicle', 'carry', 'passage', 'metal', 'engine', 'fast']
# ['ride', 'long', 'pull', 'engine', 'large', 'carry', 'loud', 'object', 'fast', 'human', 'wheel', 'travel', 'passage', 'metal', 'car', 'vehicle', 'person', 'transport', 'drive', 'move']
# ['metal', 'fly', 'door', 'car', 'passage', 'wheel', 'loud', 'large', 'human', 'hand', 'act', 'move', 'two', 'engine', 'fast', 'person', 'carry', 'transport', 'vehicle', 'drive']
# ['long', 'drive', 'four', 'wheel', 'hand', 'large', 'act', 'passage', 'person', 'metal', 'car', 'loud', 'fast', 'carry', 'vehicle', 'two', 'transport', 'move', 'human', 'water']
# ['railroad', 'run', 'electric', 'coal', 'choo', 'conduct', 'car', 'passage', 'track', 'engine', 'carry', 'cargo', 'many', 'transport', 'human', 'rail', 'freight', 'fast', 'caboose', 'wheel']
# ['conduct', 'electric', 'move', 'vehicle', 'run', 'carry', 'many', 'car', 'human', 'drive', 'cargo', 'caboose', 'fast', 'rail', 'freight', 'wheel', 'transport', 'engine', 'passage', 'track']
#
#
# fire
#
# The close-up of the ribbons , preceded by a short , almost subliminal zoom , nearly persuades us too that the fire is real , a totally unclassifiable special effect .
# ['smell', 'yellow', 'see', 'black', 'gas', 'sun', 'flame', 'warm', 'smoke', 'light', 'cook', 'destroy', 'wood', 'hot', 'red', 'danger', 'burn', 'bright', 'fire', 'heat']
# ['tree', 'see', 'gas', 'person', 'destroy', 'yellow', 'flame', 'warm', 'smoke', 'sun', 'bright', 'danger', 'red', 'hot', 'wood', 'cook', 'light', 'heat', 'fire', 'burn']
# ['hurt', 'danger', 'black', 'burn', 'smoke', 'hot', 'water', 'fire', 'sun', 'music', 'red', 'bright', 'light', 'act', 'destroy', 'cook', 'warm', 'color', 'heat', 'cold']
# ['electric', 'hurt', 'danger', 'cold', 'wood', 'smoke', 'red', 'sun', 'warm', 'black', 'color', 'hot', 'water', 'cook', 'bright', 'fire', 'burn', 'light', 'heat', 'tree']
# ['vision', 'small', 'candle', 'color', 'flame', 'smoke', 'light', 'heat', 'warm', 'yellow', 'oxygen', 'blue', 'danger', 'destroy', 'cook', 'fire', 'burn', 'red', 'hot', 'orange']
# ['act', 'black', 'hurt', 'cigar', 'oxygen', 'light', 'flame', 'yellow', 'cook', 'hot', 'orange', 'fire', 'destroy', 'red', 'burn', 'smoke', 'warm', 'danger', 'heat', 'blue']
#
#
# Ironically it seems that the personal computer Mr Anderson was using to write the book was the cause of the fire .
# ['pain', 'bright', 'break', 'cook', 'person', 'build', 'red', 'act', 'wood', 'smoke', 'human', 'heat', 'danger', 'burn', 'object', 'light', 'fire', 'hot', 'hurt', 'destroy']
# ['bright', 'yellow', 'break', 'flame', 'pain', 'build', 'smoke', 'wood', 'cook', 'object', 'heat', 'destroy', 'red', 'danger', 'burn', 'hot', 'light', 'fire', 'person', 'hurt']
# ['day', 'explode', 'smoke', 'music', 'fast', 'smell', 'person', 'hot', 'hurt', 'fire', 'act', 'light', 'heat', 'danger', 'move', 'food', 'burn', 'destroy', 'cook', 'black']
# ['smoke', 'pain', 'cold', 'heat', 'fruit', 'taste', 'red', 'tree', 'danger', 'black', 'bad', 'number', 'burn', 'water', 'destroy', 'light', 'hurt', 'cook', 'fire', 'hot']
# ['small', 'heat', 'color', 'hell', 'oxygen', 'flame', 'candle', 'light', 'yellow', 'hot', 'danger', 'burn', 'warm', 'cook', 'destroy', 'orange', 'red', 'blue', 'smoke', 'fire']
# ['act', 'black', 'hurt', 'cigar', 'oxygen', 'light', 'flame', 'yellow', 'cook', 'hot', 'orange', 'fire', 'destroy', 'red', 'burn', 'smoke', 'warm', 'danger', 'heat', 'blue']
#
#
# That way he can not be targeted by missile fire or some spells and will be potentially protected from war engines .
# ['burn', 'fight', 'body', 'destroy', 'noise', 'anger', 'human', 'move', 'intent', 'light', 'hurt', 'war', 'weapon', 'force', 'hot', 'loud', 'kill', 'act', 'danger', 'fire']
# ['destroy', 'body', 'burn', 'metal', 'intent', 'human', 'hurt', 'move', 'war', 'light', 'noise', 'force', 'loud', 'hot', 'weapon', 'danger', 'fire', 'act', 'person', 'kill']
# ['body', 'hunt', 'throw', 'sport', 'danger', 'kill', 'bird', 'fire', 'hurt', 'act', 'human', 'fly', 'person', 'large', 'weapon', 'war', 'gun', 'loud', 'light', 'hot']
# ['metal', 'bullet', 'fast', 'move', 'cook', 'fly', 'hand', 'burn', 'hurt', 'war', 'kill', 'act', 'weapon', 'fire', 'human', 'danger', 'gun', 'light', 'loud', 'hot']
# ['blue', 'human', 'destroy', 'pain', 'danger', 'cook', 'fire', 'end', 'burn', 'act', 'hunt', 'kill', 'alcohol', 'basketball', 'life', 'gun', 'orange', 'red', 'bullet', 'hot']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
#
#
# After deliberating for a little while , the priest selected one and carried it towards the fire .
# ['flame', 'hurt', 'bright', 'red', 'warm', 'sun', 'gas', 'destroy', 'object', 'black', 'danger', 'cook', 'food', 'fire', 'wood', 'light', 'burn', 'heat', 'metal', 'hot']
# ['sun', 'gas', 'kitchen', 'bright', 'black', 'hold', 'object', 'red', 'heat', 'fire', 'metal', 'hot', 'cook', 'danger', 'warm', 'burn', 'person', 'light', 'food', 'wood']
# ['electric', 'metal', 'leg', 'hand', 'red', 'eat', 'kitchen', 'warm', 'tree', 'light', 'heat', 'color', 'person', 'food', 'hot', 'fire', 'burn', 'sun', 'wood', 'cook']
# ['black', 'taste', 'cold', 'electric', 'warm', 'wood', 'hot', 'fire', 'metal', 'tree', 'person', 'red', 'burn', 'drink', 'water', 'sun', 'heat', 'light', 'cook', 'food']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['act', 'black', 'hurt', 'cigar', 'oxygen', 'light', 'flame', 'yellow', 'cook', 'hot', 'orange', 'fire', 'destroy', 'red', 'burn', 'smoke', 'warm', 'danger', 'heat', 'blue']
#
#
# Perhaps the best thing to do , I thought despairingly , was to find a telephone and get professional help : the fire brigade and an ambulance .
# ['orange', 'work', 'place', 'destroy', 'area', 'warm', 'water', 'wood', 'body', 'danger', 'fire', 'hot', 'burn', 'person', 'build', 'red', 'yellow', 'cook', 'light', 'heat']
# ['metal', 'tree', 'warm', 'orange', 'light', 'destroy', 'build', 'area', 'object', 'wood', 'red', 'hot', 'yellow', 'burn', 'heat', 'person', 'danger', 'fire', 'place', 'cook']
# ['sport', 'heat', 'car', 'color', 'build', 'fire', 'cook', 'grow', 'city', 'red', 'light', 'person', 'hot', 'fruit', 'eat', 'metal', 'place', 'water', 'green', 'burn']
# ['warm', 'danger', 'law', 'red', 'heat', 'metal', 'animal', 'kitchen', 'burn', 'cold', 'grow', 'fruit', 'electric', 'tree', 'light', 'fire', 'cook', 'person', 'water', 'hot']
# ['expense', 'use', 'not', 'communicate', 'attach', 'thing', 'heat', 'oven', 'noise', 'cook', 'correct', 'TRUE', 'lie', 'stick', 'pig', 'clear', 'roll', 'sound', 'hold', 'wrong']
# ['ground', 'lie', 'animal', 'wrong', 'salt', 'hold', 'bird', 'lift', 'cracker', 'medic', 'large', 'pain', 'key', 'stick', 'black', 'clear', 'music', 'metal', 'TRUE', 'small']
